# %% [markdown]
# <h1><center> Analyze_Histograms </center></h1>

# %% [markdown]
# **Last Modified**:<br>
# By Daniel Baur on 11th March 2019
#
# **Note**:<br>
# This notebook `Analyze_Histograms` is used to plot and further examine histograms recorded with the MonXe radon emanation chamber setup.
#
# **Organizing Structure**:<br>
# All runs are contained within the folder `Measurements`. A run is defined as a data acquisition session (e.g. 226Ra spectra recorded within one afternoon with a similar setting of parameters), summarizes a few measurements and is referenced with its `runstring` (`runstring` is basically the name of the run folder. It is comprised of a `datestring` in the format YYYYMMDD and a string summarizing the purpose of that specific run.). All of the single measurements within one run are referenced with their corresponding `measurementstring`. Accordingly (most of) the files within the `Measurements` folder follow the following naming scheme: `<runstring>__<measurementstring>`.<br>
# Primary datasets (as recorded with the MCA or oscilloscope) also come with a `parameterstring` instead of which processed files usually have a string referring to the origin or purpose of the file. The files `MCAcfg_<datestring>` are the MCA configuration files the primary datasets referr to in their appended `parameterstring`.<br>
# (Though this paragraph might have been a little confusing, I reccomend having a look into the respective folders within the `DARWIN_TaskStuff` folder - it'l become clear.

# %% [markdown]
# ### Table of Contents

# %% [markdown]
# 0. **[Stuff](#0.-Stuff)**<br>
#     0.1 [Imports](#0.1-Imports)<br>
#     0.2 [Global Definitions](#0.2-Global-Definitions)<br>
#     0.3 [Formatting](#0.3-Formatting)
#
#
# 1. **[Histograms!](#1.-Histograms!)**<br>
#     1.1 [20190307_226Ra_spectrum](#jkdsa)<br>
#     1.2 [20190315_226Ra_spectrum](#20190315_226Ra_spectrum)<br>

# %% [markdown]
# # 0. Stuff

# %% [markdown]
# ## 0.1 Imports

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.special import binom as binomcoeff
from scipy.special import erf
from scipy.optimize import curve_fit
from scipy.integrate import quad
import datetime
import pprint
import math
from matplotlib.ticker import AutoMinorLocator
import subprocess
from matplotlib.colors import LogNorm
import os
from datetime import date
from random import randint
from scipy.stats import chi2
from scipy.integrate import quad

# %% [markdown]
# ## 0.2 Global Definitions

# %% [markdown]
# ### Generic Stuff

# %%
def print_datestring():
    return str(date.today().year) + str(date.today().month).zfill(2) + str(date.today().day).zfill(2)

def get_datestring(filestring):
    return filestring[:8]

def get_runstring(filestring):
    runstring = filestring[:filestring.index("__")]
    return runstring

def get_measurementstring(filestring):
    first_two_underscores = filestring.index("__")
    second_two_underscores = filestring[first_two_underscores+2:].index("__") + len(filestring[:first_two_underscores+2])
    return filestring[first_two_underscores+2:second_two_underscores]

def get_parameterstring(filestring):
    first_two_underscores = filestring.index("__")
    second_two_underscores = filestring[first_two_underscores+2:].index("__") + len(filestring[:first_two_underscores+2])
    parameterstring = filestring[second_two_underscores+2:]
    return parameterstring

# Function to read out a certain value from the file name of a np.array file (generated with Signal_Formation()).
def read_out_value_from_string(filestring, parameter_string):
    parameter_index = filestring.index("_" +parameter_string +"_")
    cutoff_index_front = parameter_index +len(parameter_string) +2
    if "_" in filestring[cutoff_index_front:]:
        cutoff_index_back = len(filestring[:cutoff_index_front]) +filestring[cutoff_index_front:].index("_")
        value_string = filestring[cutoff_index_front:cutoff_index_back]
    else:
        value_string = filestring[cutoff_index_front:len(filestring)-4]
    return value_string

# This function is used to read in a histogram.txt file (as recorded with the MCA or the oscilloscope) located in the relative path "filestring".
# The data is then saved in the folder the .txt file wa retrieved as a np.aray whereas its name is the name of the initial file ending with .npy instead of .txt.
# The output filename is then returned as a string, so one can load the npy.file via
#     $ file = np.load(save_and_get_histogram_data_as_np_array(filestring))
def save_and_get_histogram_data_as_np_array_from_file(filestring):
    # Defining the initial variables.
    histo_dtype = np.dtype([
        ("adc_channel", np.uint16),
        ("counts", np.uint16),
        ])
    output_tuple_list = []
    # Writing the data from the file to "output_tuple_list".
    f = open("Measurements/" +get_runstring(filestring) +"/" +filestring)
    for line in f:
        row_tuple = (int(line.strip().split(" ")[0]),int(line.strip().split(" ")[1]))
        output_tuple_list.append(row_tuple)
        #print(row_tuple)
        #else:
            #print(row)
            #NEST_output = [float(row[0]), float(row[1]),  int(row[4]),  int(row[5])]  # order of the NEST output per simulated event: [E [keV],  field [V/cm],  Nph,  Ne-]
            #NEST_output_list.append(NEST_output)
    f.close()
    # Converting and saving "output_tuple_list" to/as np.array into the same directory the original file was retrieved from.
    output_array = np.array(output_tuple_list, histo_dtype)
    np.save("Measurements/" +get_runstring(filestring) +"/" +filestring[:-4] +".npy", output_array)
    # Returning the name of the np.array file (with precedent directory) so one can easily retrieve the data.
    return "Measurements/" +get_runstring(filestring) +"/" +filestring[:-4] +".npy"




# This function is used to read out the parameters from the txt_filestring of a measurement dataset (e.g. as recorded with the MCA) and convert them into a string that can be plotted directly onto the canvas of the plot.
def write_parameters_to_canvas_text_block(filestring):
    
    # Initializing variables.
    txt_parameterstring = "_" +get_parameterstring(filestring=filestring) 
    printstring = "nooneissupposedtoreadthisanyhowasitisjustusedtopfuschwiththeuseoflatexandpython\\\\[14.0cm]\\textbf{Setup}:\\\\[0.8cm]"
    
    # The "plot_dictionary" dictonary contains various parameters that might occur within the input "filestring" string as keys.
    # Its values are (supposed to be) lists with the following elements:
    # [0]: (string) The name of the parameter as it is supposed to be displayed on the canvas of the plot.
    # [1]: (string) The value of the key string as it is read out from the input "filestring" string.
    # [2]: (string) A string resembling a strange LaTEX/Python3 hybrid that will later on be printed onto the canvas.
    # As [1] and [2] will be appended within the following lines, only [0] can be specified as of now.    
    plot_dictionary = {
        "source":["source: "],
        "readout":["readout: "],
        "coll":["collection voltage: "],
        "bias":["bias voltage: "],
        "amp":["amplifier: "],
        "vessel":["vessel: "],
        "date":["date: ", get_datestring(filestring=filestring), "date: " +get_datestring(filestring=filestring) +"\\\\[0.4cm]"]
    }
    
    # Looping over "plot_dictionary" and appending value[1] and value[2] to value.
    # If the respective key is not part of "txt_filestring", no value is read out and the length of value remains 1 instead of 3.
    for key, value in plot_dictionary.items():
        if key in txt_parameterstring:
            value.append(read_out_value_from_string(filestring=txt_parameterstring, parameter_string=key))
            appendstring = ""
            if key == "source":
                if value[1] == "226Ramasked":
                    appendstring = value[0] +"$^{226}\\mathrm{Ra}$ (masked, in air)" +"\\\\[0.4cm]"
            if key == "readout":
                if value[1][:3] == "MCA":
                    appendstring = value[0] +"MCA " +"(.css file: " +value[1][3:] +")" +"\\\\[0.4cm]"
            if key == "amp":
                if value[1] == "v3.1":
                    appendstring = value[0] +value[1] +"\\\\[0.4cm]"
            if key == "vessel":
                if value[1] == "PastaPot":
                    appendstring = value[0] +value[1] +"\\\\[0.55cm]"
            if key == "coll":
                appendstring = value[0] +"$U_{\\mathrm{coll}}=" +"-" +value[1] +"\\," +"\\mathrm{V}$" +"\\\\[0.4cm]"
            if key == "bias":
                appendstring = value[0] +"$U_{\\mathrm{bias}}=" +value[1] +"\\," +"\\mathrm{V}$" +"\\\\[0.4cm]"
            value.append(appendstring)
        printstring = printstring +value[2]

    return printstring

# %% [markdown]
# ## 0.3 Formatting

# %% [markdown]
# ### Using Latex Fonts for Fancy Nancy Plots

# %%
# These two lines are used to deploy LaTEX for the Fonts within an output figure.
# note1: All the necessary packages for this should already be imported for your AG Schumann Linux machine by default.
# note2: If you installed jupyter notebook on an external machine install the following packages in advance: $ sudo apt-get install font-manager texlive-latex-extra texlive-math-extra dvipng texlive-fonts-recommended
# note3: Should jupyter notebook throw an "OSError: error reading PNG HEADER" error, try reducing the dpi-value of the image.
# %pylab inline
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

# Since Latex does interpret "_" as a command to underscore the previous phrase one has to replace it with "\_".
def tex_naming(string):
    latex_string = string.replace("_", "\\_")
    return latex_string
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['erf', 'axes', 'axis', 'randint']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## 0.4 Fitting

# %% [markdown]
# ### Mathematical Functions

# %%
# Function to define a gaussian curve with amplitude "A", mean "mu" and sigma "sigma".
def gauss_function(x,A,mu,sigma):
    return A/np.sqrt(2*np.pi*sigma**2)*np.exp(-(x-mu)**2/(2*sigma**2))

# Function to define a Crystall Ball curve.
# See Stefan Bruenner's Thesis (p.30) for more details.
def crystal_ball_function(x, mu, sigma, alpha, n, N) -> float: # evtl. N als Parameter
    A = (n/abs(alpha))**n *np.exp(-((abs(alpha)**2)/(2)))
    B = (n/abs(alpha)) -abs(alpha)
    if sigma == 0:
        comp_val = 12
    else:
        comp_val = (float(x)-float(mu))/float(sigma)
    #C = (n/abs(alpha)) *(1/(n-1)) *np.exp(-((abs(alpha)**2)/(2)))
    #D = np.sqrt(math.pi/2) *(1 +erf(abs(alpha)/np.sqrt(2)))
    #N = 1/(sigma*(C+D))
    if comp_val > (-1)*alpha:
        return N * np.exp(-(((x-mu)**2)/(2*sigma**2)))
    if comp_val <= (-1)*alpha:
        return N * A* (B - ((x-mu)/(sigma)))**(-n)

# curve_fit() has problems fitting piecewise defined functions, such as crystal_ball_function().
# Online I found, that one has to vectorize the function in order for curve_fit() to be able to fit it properly.
# Here's the corresponding link I found (accessed 12th March 2019): https://stackoverflow.com/questions/11129812/fitting-piecewise-function-in-python
def crystal_ball_function_vec_self(x, mu, sigma, alpha, n, N):
    y = np.zeros(x.shape)
    for i in range(len(y)):
        y[i]=crystal_ball_function(x[i], mu, sigma, alpha, n, N)
    return y


# Function to define a quadruple Crystal Ball curve utilizing the (single) Crystal Ball Curve defined above.
def quad_crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3):
    return crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0) +crystal_ball_function(x, mu_1, sigma_1, alpha_1, n_1, N_1) +crystal_ball_function(x, mu_2, sigma_2, alpha_2, n_2, N_2) +crystal_ball_function(x, mu_3, sigma_3, alpha_3, n_3, N_3)

# curve_fit() has problems fitting piecewise defined functions, such as quad_crystal_ball_function().
# Online I found, that one has to vectorize the function in order for curve_fit() to be able to fit it properly.
# Here's the corresponding link I found (accessed 12th March 2019): https://stackoverflow.com/questions/11129812/fitting-piecewise-function-in-python
def quad_crystal_ball_function_vec_self(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3):
    y = np.zeros(x.shape)
    for i in range(len(y)):
        y[i]=quad_crystal_ball_function(x[i], mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3)
    return y

# Function to define a quadruple Crystal Ball curve utilizing the (single) Crystal Ball Curve defined above.
def quint_crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3, mu_4, sigma_4, alpha_4, n_4, N_4):
    return crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0) +crystal_ball_function(x, mu_1, sigma_1, alpha_1, n_1, N_1) +crystal_ball_function(x, mu_2, sigma_2, alpha_2, n_2, N_2) +crystal_ball_function(x, mu_3, sigma_3, alpha_3, n_3, N_3) +crystal_ball_function(x, mu_4, sigma_4, alpha_4, n_4, N_4)

# Vectorization of quint_crystal_ball_function()
def quint_crystal_ball_function_vec_self(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3, mu_4, sigma_4, alpha_4, n_4, N_4):
    y = np.zeros(x.shape)
    for i in range(len(y)):
        y[i]=quint_crystal_ball_function(x[i], mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3, mu_4, sigma_4, alpha_4, n_4, N_4)
    return y

# %%
# Function to define a linear curve with slope m and intercept t.
def linear_function(x, m, t):
    return (x*m) +t

# Function to define a gaussian curve with amplitude "A", mean "mu" and sigma "sigma".
def gauss_function(x,A,mu,sigma):
    return A/np.sqrt(2*np.pi*sigma**2)*np.exp(-(x-mu)**2/(2*sigma**2))

# Function to define a Crystall Ball curve.
# See Stefan Bruenner's Thesis (p.30) for more details.
def crystal_ball_function(x, mu, sigma, alpha, n, N) -> float: # evtl. N als Parameter
    A = (n/abs(alpha))**n *np.exp(-((abs(alpha)**2)/(2)))
    B = (n/abs(alpha)) -abs(alpha)
    if sigma == 0:
        comp_val = 12
    else:
        comp_val = (float(x)-float(mu))/float(sigma)
    #C = (n/abs(alpha)) *(1/(n-1)) *np.exp(-((abs(alpha)**2)/(2)))
    #D = np.sqrt(math.pi/2) *(1 +erf(abs(alpha)/np.sqrt(2)))
    #N = 1/(sigma*(C+D))
    if comp_val > (-1)*alpha:
        return N * np.exp(-(((x-mu)**2)/(2*sigma**2)))
    if comp_val <= (-1)*alpha:
        return N * A* (B - ((x-mu)/(sigma)))**(-n)

# curve_fit() has problems fitting piecewise defined functions, such as crystal_ball_function().
# Online I found, that one has to vectorize the function in order for curve_fit() to be able to fit it properly.
# Here's the corresponding link I found (accessed 12th March 2019): https://stackoverflow.com/questions/11129812/fitting-piecewise-function-in-python
def crystal_ball_function_vec_self(x, mu, sigma, alpha, n, N):
    y = np.zeros(x.shape)
    for i in range(len(y)):
        y[i]=crystal_ball_function(x[i], mu, sigma, alpha, n, N)
    return y


# Function to define a quadruple Crystal Ball curve utilizing the (single) Crystal Ball Curve defined above.
def quad_crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3):
    return crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0) +crystal_ball_function(x, mu_1, sigma_1, alpha_1, n_1, N_1) +crystal_ball_function(x, mu_2, sigma_2, alpha_2, n_2, N_2) +crystal_ball_function(x, mu_3, sigma_3, alpha_3, n_3, N_3)

# curve_fit() has problems fitting piecewise defined functions, such as quad_crystal_ball_function().
# Online I found, that one has to vectorize the function in order for curve_fit() to be able to fit it properly.
# Here's the corresponding link I found (accessed 12th March 2019): https://stackoverflow.com/questions/11129812/fitting-piecewise-function-in-python
def quad_crystal_ball_function_vec_self(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3):
    y = np.zeros(x.shape)
    for i in range(len(y)):
        y[i]=quad_crystal_ball_function(x[i], mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3)
    return y

# Function to define a quadruple Crystal Ball curve utilizing the (single) Crystal Ball Curve defined above.
def quint_crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3, mu_4, sigma_4, alpha_4, n_4, N_4):
    return crystal_ball_function(x, mu_0, sigma_0, alpha_0, n_0, N_0) +crystal_ball_function(x, mu_1, sigma_1, alpha_1, n_1, N_1) +crystal_ball_function(x, mu_2, sigma_2, alpha_2, n_2, N_2) +crystal_ball_function(x, mu_3, sigma_3, alpha_3, n_3, N_3) +crystal_ball_function(x, mu_4, sigma_4, alpha_4, n_4, N_4)

# Vectorization of quint_crystal_ball_function()
def quint_crystal_ball_function_vec_self(x, mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3, mu_4, sigma_4, alpha_4, n_4, N_4):
    y = np.zeros(x.shape)
    for i in range(len(y)):
        y[i]=quint_crystal_ball_function(x[i], mu_0, sigma_0, alpha_0, n_0, N_0, mu_1, sigma_1, alpha_1, n_1, N_1, mu_2, sigma_2, alpha_2, n_2, N_2, mu_3, sigma_3, alpha_3, n_3, N_3, mu_4, sigma_4, alpha_4, n_4, N_4)
    return y

# %% [markdown]
# ### Helpful Functions

# %%
# fit_range// function to narrow down a dataset to only fit a certain parameter space
# input//   x,y: lists of the same length representing data
#           x_min, x_max: integer values to whicht the fit parameter space is adapted to
# output//  x_new, y_new: new lists used as basis for the following fit
def fit_range(x,y,x_min, x_max):
    list_beg = x.index(x_min)
    list_end = x.index(x_max)
    x_new = np.zeros(list_end - list_beg + 1)
    y_new = np.zeros(list_end - list_beg + 1)
    for i in range(len(x_new)):
        x_new[i] = x[list_beg+i]
        y_new[i] = y[list_beg+i]
    return x_new, y_new

# This function is used to fit an arbitrary function to a dataset within a specified x value interval.
def fit_range_function(x,y,x_min, x_max, function, guess=0, bounds=0):
    x_new, y_new = fit_range(x,y,x_min, x_max)
    if bounds == 0:
        if guess ==0:
            p_opt, p_cov = curve_fit(function, x_new, y_new, method='lm')  # curve_fit returns x-position, amplitude and sigma to first variable popt
        else:
            p_opt, p_cov = curve_fit(function, x_new, y_new, p0=guess, method='lm')  # curve_fit returns x-position, amplitude and sigma to first variable popt
        return p_opt, p_cov # p_opt carries the fitted parameters for the function specified (in the order as it is specified upon definition).
    if bounds != 0:
        if guess ==0:
            p_opt, p_cov = curve_fit(function, x_new, y_new, bounds=bounds, method='lm')  # curve_fit returns x-position, amplitude and sigma to first variable popt
        else:
            p_opt, p_cov = curve_fit(function, x_new, y_new, p0=guess, bounds=bounds, method='lm')  # curve_fit returns x-position, amplitude and sigma to first variable popt
        return p_opt, p_cov # p_opt carries the fitted parameters for the function specified (in the order as it is specified upon definition).

# This function is used to generate two lists resembling x and y values of a function in a specified interval.
def get_function_values_for_plot(x_min, x_max, stepwidth, function, **kwargs):
    x_list = np.arange(x_min, x_max+stepwidth, stepwidth).tolist()
    y_list = np.zeros_like(x_list).tolist()
    for i in range(len(y_list)):
        y_list[i] = function(x=x_list[i], **kwargs)
    return x_list, y_list

# %% [markdown]
# ### Fit Analysis

# %%
# This is a selfmade chi square test function.
# I wrote it so I could test whether the functions I fitted to a data sample resembled them.
# Note that chi_square is lower (i.e. better), if "number_of_categories" is a divider of "sample_values_max"-"sample_values_min".
def chi_square_test_for_costum_function(sample_values, sample_counts, sample_values_min, sample_values_max, function, number_of_categories=10, significance=0.95, **function_parameters):
    
    # Narrowing down the sample size according to the interval specified by "sample_values_min" and "sample_values_max".
    function_parameters_tuple = ()
    for key, value in function_parameters.items():
        function_parameters_tuple = function_parameters_tuple +(value,)
    mask = (sample_values >= sample_values_min) & (sample_values < sample_values_max)
    sample_values_new = sample_values[mask]
    sample_counts_new = sample_counts[mask]
    total_number_of_counts = sum(sample_counts_new)
    #print(sum(sample_counts))
    #print(total_number_of_counts)
    total_integral = quad(func=function, a=sample_values_min-0.5, b=sample_values_max-0.5, args=function_parameters_tuple)[0]

    # Defining the "number_of_categories"-many categories the sample is divided into.
    category_edges = np.linspace(sample_values_min, sample_values_max, number_of_categories+1, endpoint=True)
    #print(category_edges)
    category_list = []
    
    # Now for all of the categories defined above a tuple containing
    # (index of the category, actual counts within the category, expected counts within the category)
    # is generated and appended to "category_list". Afterwards "category_list" is converted into a np.array.
    for i, low_edge in enumerate(category_edges[:-1]):
        high_edge = category_edges[i+1]-1
        edge_mask = (sample_values_new >= low_edge) & (sample_values_new <= high_edge)
        masked_adc_channels = sample_values_new[edge_mask]
        masked_counts = sample_counts_new[edge_mask]
        actual_counts_in_category = sum(masked_counts)
        partial_integral = quad(func=function, a=low_edge-0.5, b=high_edge+0.5, args=function_parameters_tuple)[0]
        expected_counts_in_category = (partial_integral/total_integral)*total_number_of_counts
        category_tuple = (i, low_edge, high_edge, actual_counts_in_category, expected_counts_in_category)
        category_list.append(category_tuple)
    tuple_dtype = np.dtype([
        ("index", np.uint16),
        ("left_edge", np.float32),
        ("right_edge", np.float32),
        ("actual_counts", np.float32),
        ("expected_counts", np.float32),
    ])
    category_array = np.array(category_list, tuple_dtype)
    #print("total measured: {}".format(sum(sample_counts_new)))
    #print("total measured in array: {}".format(sum(category_array["actual_counts"])))
    #print("total expected in array: {}".format(sum(category_array["expected_counts"])))
    #for i in range(len(category_array["actual_counts"])):
        #print((category_array["actual_counts"][i], category_array["expected_counts"][i]))
    
    # Calculating the chi square value with the scipy.stats.chisquare() function and the critical chi square value (that should not be exceeded) with the  function.
    chi_square = 0
    for i in range(len(category_array["actual_counts"])):
        chi_square = chi_square + (((category_array["actual_counts"][i] -category_array["expected_counts"][i])**2)/(category_array["expected_counts"][i]))
    chi_square_crit = chi2.isf(q=significance, df=number_of_categories-1)
    #chi_square, p = chisquare(f_obs=category_array["actual_counts"], f_exp=["expected_counts"])
    return chi_square, chi_square_crit

# %% [markdown]
# # 1. Histograms!

# %% [markdown]
# ## 1.1 20190307_226Ra_spectrum
# <a id='jkdsa'></a>

# %% [markdown]
# ### Simple 2D Plot (can be used as a template)

# %%
txt_filestring = "20190307_226Ra_spectrum__226Ra_spectrum__readout_osci_colll_1000_masked_True_MCAcfg_2019030701.txt"
file = np.load(save_and_get_histogram_data_as_np_array_from_file(filestring=txt_filestring))



# PLOTTING!
FLAG_2d_plot = True

if FLAG_2d_plot == True:

    # Figure
    fig=plt.figure(figsize=(21, 10.5), dpi=150)  # <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    
    # Plotting
    plt.plot(file["adc_channel"], file["counts"], marker=",", linewidth=5, c="cyan", alpha=0.75, label="Notenschluessel")
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    

    # Axes Settings
    ## Title
    title_string = "$^{226}\mathrm{Ra}$ Spectrum"
    plt.title(title_string, fontsize=26, pad=15)
    ## Axes ---> Labels
    plt.xlabel("ADC Channels", fontsize=24, labelpad = 18)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel("Counts", fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    ## Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
    ## Axes ---> Range  
    plt.xlim(1000,8500)
    plt.ylim(0,2500)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    # Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
    # Axes ---> Shading
    #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
    # Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    # Colorbar 
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    # Plot Size
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.80, top=0.93, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    # Legend
    #leg = plt.legend(loc=3, bbox_to_anchor=(0.52,0.78), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
    #for line in leg.get_lines(): # enumerated
    #    line.set_linewidth(4)
    #leg.get_frame().set_linewidth(2.5)
    #for lh in leg.legendHandles: 
    #    lh.set_alpha(1)

    # Text
    # For positioning the text on the right hand side of the plot.
    #plt.text(1.16, 0.40, text_string, fontsize=22, transform = axes.transAxes)
    # For positioning the text within the plot canvas.
    #plt.text(0.08, 0.33, text_string, fontsize=22, transform = axes.transAxes)

    # Saving
    save_string = "spectrum_plot"
    format_string = ".png"
    fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)

# %%
if FLAG_2d_plot == True:

    # Figure
    fig=plt.figure(figsize=(21, 10.5), dpi=150)  ### <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    #frame1=fig.add_axes((.1,.3,.8,.6)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))


    # Plotting
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    
    #plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Quadruple Crystal Ball Fit")
        
    ## Plotting the data itself.
    plt.scatter(file["adc_channel"], file["counts"], marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None, label="$^{226}\mathrm{Ra}$ Spectrum Data")
    
    
    ## Plotting a gaussian fit for the 214Po Peak (the fit is done only for the right half).
    #plt.plot(gauss_fit_x_values, gauss_fit_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Fit: $\mu_\mathrm{G}=\,$" +str(gauss_fit_mu) +"$,\,\,\sigma_\mathrm{G}=\,$" +str(gauss_fit_sigma))
    
    # Axes Settings
    ## Title
    title_string = "$\\boldsymbol{^{226}\mathrm{Ra}}$ \\textbf{Spectrum}"
    plt.title(title_string, fontsize=26, pad=15)
    ## Axes ---> Labels
    plt.xlabel("\\textbf{Energy }$\\boldsymbol{[\\mathrm{adc}]}$", fontsize=24, labelpad = 18)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel("\\textbf{Counts}", fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    ## Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
    ## Axes ---> Range  
    plt.xlim(1000,8500)
    plt.ylim(0,2500)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    # Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
    # Axes ---> Shading
    #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
    # Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    # Colorbar 
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    # Plot Size
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.90, top=0.90, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    # Legend
    #handles, labels = plt.gca().get_legend_handles_labels()
    #order = [5,0,1,3,2,4]
    #leg = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=3, bbox_to_anchor=(0.62,0.61), fontsize = 18, frameon=True, shadow=False, edgecolor='black', fancybox=False)

    # leg = plt.legend(loc=3, bbox_to_anchor=(0.62,0.61), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)   # <--- If you don't care about the order of arguments within the legend.
    #for line in leg.get_lines(): # enumerated
    #    line.set_linewidth(4)
    #leg.get_frame().set_linewidth(2.5)
    #for lh in leg.legendHandles: 
    #    lh.set_alpha(1)

    # Text
    # For positioning the text on the right hand side of the plot.
    #plt.text(1.16, 0.40, text_string, fontsize=22, transform = axes.transAxes)
    # For positioning the text within the plot canvas.
    plt.text(0.02, 0.450, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
    #plt.text(0.30, 0.80, "$^{226}\mathrm{Ra}$", fontsize=22, transform = axes.transAxes)
    #plt.text(0.40, 0.89, "$^{222}\mathrm{Rn}$", fontsize=22, transform = axes.transAxes)
    #plt.text(0.52, 0.44, "$^{218}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
    #plt.text(0.80, 0.42, "$^{214}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)

    # Saving
    save_string = "spectrum_plot_just_histo"
    format_string = ".png"
    fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)
# Out:
# source: $^{226}\mathrm{Ra}$ (masked, in air)\\[0.4cm]
# readout: MCA (.css file: 2019030701)\\[0.4cm]
# collection voltage: $U_{\mathrm{coll}}=-1000\,\mathrm{V}$\\[0.4cm]
# bias voltage: $U_{\mathrm{bias}}=10\,\mathrm{V}$\\[0.4cm]
# amplifier: v3.1\\[0.4cm]
# vessel: PastaPot\\[0.55cm]
# date: 20190307\\[0.4cm]

# %%
txt_filestring = "20190307_226Ra_spectrum__226Ra_spectrum__source_226Ramasked_readout_MCA2019030701_amp_v3.1_vessel_PastaPot_coll_1000_bias_10.txt"

FLAG_plot = True

FLAG_fits = False
FLAG_text = True
FLAG_legend = True
FLAG_plot_residual_canvas = False
FLAG_save = True


##################################################################################
###   Loading the .txt File.
##################################################################################

file = np.load(save_and_get_histogram_data_as_np_array_from_file(filestring=txt_filestring))



##################################################################################
###   Fitting
##################################################################################

if FLAG_fits == True:

    ### Gaussian fit.
    #### Fitting.
    popt_gauss, pcov_gauss = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=7300, x_max=7900, function=gauss_function, guess=(1,7300,100))
    #### Generating plottable lists.
    gauss_fit_x_values, gauss_fit_y_values = get_function_values_for_plot(x_min=6000, x_max=9000, stepwidth=1, function=gauss_function, A=popt_gauss[0], mu=popt_gauss[1], sigma=popt_gauss[2])
    #### Reading out fit parameters.
    gauss_fit_mu = round(popt_gauss[1],1)
    gauss_fit_sigma = round(popt_gauss[2],1)

    ### Quadruple Crystal Ball fit.
    #### Fitting.
    popt_qcb, pcov_qcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=1000, x_max=7900, function=quad_crystal_ball_function_vec_self, guess=(3600, 200, 1, 1, 500, 4500, 200, 1, 1, 500, 5300, 200, 1, 1, 500, 7400, 200, 1, 1, 500))
    #### Generating plottable data lists.
    qcb_fit_x_values, qcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=quad_crystal_ball_function, mu_0=popt_qcb[0], sigma_0=popt_qcb[1], alpha_0=popt_qcb[2], n_0=popt_qcb[3], N_0=popt_qcb[4], mu_1=popt_qcb[5], sigma_1=popt_qcb[6], alpha_1=popt_qcb[7], n_1=popt_qcb[8], N_1=popt_qcb[9], mu_2=popt_qcb[10], sigma_2=popt_qcb[11], alpha_2=popt_qcb[12], n_2=popt_qcb[13], N_2=popt_qcb[14], mu_3=popt_qcb[15], sigma_3=popt_qcb[16], alpha_3=popt_qcb[17], n_3=popt_qcb[18], N_3=popt_qcb[19])
    ##### 226Ra Peak
    qcb_fit_mu_0 = round(popt_qcb[0],1)
    qcb_fit_sigma_0 = round(popt_qcb[1],1)
    qcb_fit_alpha_0 = round(popt_qcb[2],1)
    qcb_fit_n_0 = round(popt_qcb[3],1)
    qcb_fit_N_0 = round(popt_qcb[4],1)
    print(qcb_fit_mu_0)
    ##### 222Rn Peak
    qcb_fit_mu_1 = round(popt_qcb[5],1)
    qcb_fit_sigma_1 = round(popt_qcb[6],1)
    qcb_fit_alpha_1 = round(popt_qcb[7],1)
    qcb_fit_n_1 = round(popt_qcb[8],1)
    qcb_fit_N_1 = round(popt_qcb[9],1)
    print(qcb_fit_mu_1)
    ##### 218Po Peak
    qcb_fit_mu_2 = round(popt_qcb[10],1)
    qcb_fit_sigma_2 = round(popt_qcb[11],1)
    qcb_fit_alpha_2 = round(popt_qcb[12],1)
    qcb_fit_n_2 = round(popt_qcb[13],1)
    qcb_fit_N_2 = round(popt_qcb[14],1)
    print(qcb_fit_mu_2)
    print(qcb_fit_N_2)
    ##### 214Po Peak
    qcb_fit_mu_3 = round(popt_qcb[15],1)
    qcb_fit_sigma_3 = round(popt_qcb[16],1)
    qcb_fit_alpha_3 = round(popt_qcb[17],1)
    qcb_fit_n_3 = round(popt_qcb[18],1)
    qcb_fit_N_3 = round(popt_qcb[19],1)
    print(qcb_fit_mu_3)
    print(qcb_fit_N_3)
    #### Generating single Crystal Ball data.
    Ra226_cb_fit_x_values, Ra226_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_0, sigma=qcb_fit_sigma_0, alpha=qcb_fit_alpha_0, n=qcb_fit_n_0, N=qcb_fit_N_0)
    Rn222_cb_fit_x_values, Rn222_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_1, sigma=qcb_fit_sigma_1, alpha=qcb_fit_alpha_1, n=qcb_fit_n_1, N=qcb_fit_N_1)
    Po218_cb_fit_x_values, Po218_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    Po214_cb_fit_x_values, Po214_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)

    ### Generating single Gaussian data
    small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_2, A=5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_2, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    gauss_Po218_x_values, gauss_Po218_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_3, A=5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)
    crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_3, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)
    scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    gauss_Po214_x_values, gauss_Po214_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)

    ### Generating residual data
    res_x_data = []
    res_y_data = []
    for i in range(len(file["adc_channel"])):
        res_x_data.append(file["adc_channel"][i])
        res_y_data.append(file["counts"][i]-quad_crystal_ball_function(x=file["adc_channel"][i], mu_0=qcb_fit_mu_0, sigma_0=qcb_fit_sigma_0, alpha_0=qcb_fit_alpha_0, n_0=qcb_fit_n_0, N_0=qcb_fit_N_0, mu_1=qcb_fit_mu_1, sigma_1=qcb_fit_sigma_1, alpha_1=qcb_fit_alpha_1, n_1=qcb_fit_n_1, N_1=qcb_fit_N_1, mu_2=qcb_fit_mu_2, sigma_2=qcb_fit_sigma_2, alpha_2=qcb_fit_alpha_2, n_2=qcb_fit_n_2, N_2=qcb_fit_N_2, mu_3=qcb_fit_mu_3, sigma_3=qcb_fit_sigma_3, alpha_3=qcb_fit_alpha_3, n_3=qcb_fit_n_3, N_3=qcb_fit_N_3))



##################################################################################
###   Plotting.
##################################################################################

if FLAG_plot == True:

    #######################################################################################################################################
    ###   Defining Figure and Frame
    #######################################################################################################################################
    
    fig=plt.figure(figsize=(21, 10.5), dpi=150)  # <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    if FLAG_plot_residual_canvas == True:
        frame1=fig.add_axes((.1,.3,.8,.6)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))
    else: 
        frame1=fig.add_axes((.1,.1,.8,.8)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))

    #######################################################################################################################################
    ###   Plotting Data
    #######################################################################################################################################
    
    ### Plotting histogram, scatter plot or line plot.
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    
    #plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Quadruple Crystal Ball Fit")
        
    ### Plotting the data itself.
    plt.scatter(file["adc_channel"], file["counts"], marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None, label="$^{226}\mathrm{Ra}$ Spectrum Data")
    
    if FLAG_fits == True:
        
        ### Plotting the quadruple Crystal Ball fit.
        plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="cyan", alpha=1, label="Quadruple Crystal Ball Fit")
    
        ### Plotting the Crystal Ball curves resulting from the quadruple Crystal Ball fit.
        #plt.plot(Ra226_cb_fit_x_values, Ra226_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{226}\mathrm{Ra}$")
        #plt.plot(Rn222_cb_fit_x_values, Rn222_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{222}\mathrm{Rn}$")
        plt.plot(Po218_cb_fit_x_values, Po218_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{218}\mathrm{Po}$")
        plt.plot(Po214_cb_fit_x_values, Po214_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting the relevant gaussians resulting from the quadruple Crystal Ball fit.
        plt.plot(gauss_Po218_x_values, gauss_Po218_y_values, marker=",", linewidth=5, c="blue", alpha=0.75, label="Gaussian Curve: $^{218}\mathrm{Po}$")
        plt.plot(gauss_Po214_x_values, gauss_Po214_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting a gaussian fit for the 214Po Peak (the fit is done only for the right half).
        #plt.plot(gauss_fit_x_values, gauss_fit_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Fit: $\mu_\mathrm{G}=\,$" +str(gauss_fit_mu) +"$,\,\,\sigma_\mathrm{G}=\,$" +str(gauss_fit_sigma))
    
    #######################################################################################################################################
    ###   Axes Settings
    #######################################################################################################################################
    
    ### Title
    title_string = "$\\boldsymbol{^{226}\mathrm{Ra}}$ \\textbf{Spectrum}"
    plt.title(title_string, fontsize=28, pad=15)
    
    ### Axes ---> Labels
        #plt.xlabel("\\textbf{$\\boldsymbol{F=ma}$}", fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    xaxisstring = "\\textbf{Energy }$\\boldsymbol{[\\mathrm{adc}]}$"
    yaxisstring = "\\textbf{Counts}"
    if FLAG_plot_residual_canvas == True:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    else:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 15.5)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel(yaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    
    ### Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
        
    ### Axes ---> Range  
    plt.xlim(1000,8500)
    plt.ylim(0,2500)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    
    ### Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    if FLAG_plot_residual_canvas == True:
        plt.setp(axes.get_xticklabels(), visible=False)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([])
    
    ### Axes ---> Shading
    #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
    
    ### Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    #######################################################################################################################################
    ###   Colorbar
    #######################################################################################################################################
    
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    #######################################################################################################################################
    ###   Plot Size
    #######################################################################################################################################
    
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.80, top=0.93, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    #######################################################################################################################################
    ###   Legend
    #######################################################################################################################################
    
    if FLAG_legend == True:
    
        if FLAG_plot_residual_canvas == True:
            handles, labels = plt.gca().get_legend_handles_labels()
            order = [5,0,1,3,2,4]
            leg = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=3, bbox_to_anchor=(0.69,0.51), fontsize = 18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
        else:
            leg = plt.legend(loc=3, bbox_to_anchor=(0.68,0.71), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
            
        for line in leg.get_lines(): # enumerated
            line.set_linewidth(4)
        leg.get_frame().set_linewidth(2.5)
        for lh in leg.legendHandles: 
            lh.set_alpha(1)

    #######################################################################################################################################
    ###   Text
    #######################################################################################################################################
    
        plt.text(0.29, 0.82, "$^{226}\mathrm{Ra}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.39, 0.90, "$^{222}\mathrm{Rn}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.54, 0.57, "$^{218}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.80, 0.42, "$^{214}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
        
    if FLAG_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.02, 0.30, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        else:
            plt.text(0.02, 0.450, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        
    #######################################################################################################################################
    ###   Residual Canvas
    #######################################################################################################################################
    
    if FLAG_plot_residual_canvas == True:
        frame2=fig.add_axes((.1,.1,.8,.2))
    
        # Plotting
        plt.scatter(res_x_data, res_y_data, marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None)#, label="Residuals")
    
        # Axes Settings
        plt.ylabel("\\textbf{Residuals}", fontsize=24, labelpad = 9)   # <--- Specifying the x-axis label along with its (self explaining) properties.
        axes2 = plt.gca()
        axes2.tick_params(axis='both')
        for axis in ['top','bottom','left','right']:
            axes2.spines[axis].set_linewidth(2.2)
        ## Axes ---> Range  
        plt.xlim(1000,8500)
        plt.ylim(-150,+150)
        #plt.yscale("log")
        # Axes ---> Ticks
        axes2.xaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
        axes2.yaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
        plt.yticks([-100,0,100])
        #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
        # Axes ---> Shading
        #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
        # Axes ---> Horizontal/Vertical Lines
        #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
        #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)
        axes2.axhline(y=0.0, xmin=0, xmax=10000, color="black", linestyle="--", linewidth=2.0)
    
    #######################################################################################################################################
    ###   Saving
    #######################################################################################################################################
    
    if FLAG_save == True:
        save_string = "spectrum_plot_fits_residuals"
        format_string = ".png"
        fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)
# Out:
# source: $^{226}\mathrm{Ra}$ (masked, in air)\\[0.4cm]
# readout: MCA (.css file: 2019030701)\\[0.4cm]
# collection voltage: $U_{\mathrm{coll}}=-1000\,\mathrm{V}$\\[0.4cm]
# bias voltage: $U_{\mathrm{bias}}=10\,\mathrm{V}$\\[0.4cm]
# amplifier: v3.1\\[0.4cm]
# vessel: PastaPot\\[0.55cm]
# date: 20190307\\[0.4cm]

# %% [markdown]
# ## 1.2   20190315_226Ra_spectrum
# <a id='20190315_226Ra_spectrum'></a>

# %% [markdown]
# $U_{\mathrm{coll}}=0\,\mathrm{V}$

# %%
txt_filestring = "20190315_226Ra_spectrum__226Ra_spectrum__source_226Ramasked_readout_MCA20190310_amp_v3.1_vessel_PastaPot_coll_0_bias_9.txt"

FLAG_plot = True

FLAG_fits = True
FLAG_text = True
FLAG_legend = True
FLAG_plot_residual_canvas = False
FLAG_save = True


##################################################################################
###   Loading the .txt File.
##################################################################################

file = np.load(save_and_get_histogram_data_as_np_array_from_file(filestring=txt_filestring))



##################################################################################
###   Fitting
##################################################################################

if FLAG_fits == True:

    ### Gaussian fit.
    #### Fitting.
    #popt_gauss, pcov_gauss = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=7300, x_max=7900, function=gauss_function, guess=(1,7300,100))
    #### Generating plottable lists.
    #gauss_fit_x_values, gauss_fit_y_values = get_function_values_for_plot(x_min=6000, x_max=9000, stepwidth=1, function=gauss_function, A=popt_gauss[0], mu=popt_gauss[1], sigma=popt_gauss[2])
    #### Reading out fit parameters.
    #gauss_fit_mu = round(popt_gauss[1],1)
    #gauss_fit_sigma = round(popt_gauss[2],1)

    ### Quadruple Crystal Ball fit.
    #### Fitting.
    popt_qcb, pcov_qcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=2000, x_max=9500, function=quad_crystal_ball_function_vec_self, guess=(4000, 180, 1, 1, 125, 4800, 180, 1, 1, 160, 5900, 180, 1, 1, 75, 8600, 180, 1, 1, 75))
    #### Generating plottable data lists.
    qcb_fit_x_values, qcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=quad_crystal_ball_function, mu_0=popt_qcb[0], sigma_0=popt_qcb[1], alpha_0=popt_qcb[2], n_0=popt_qcb[3], N_0=popt_qcb[4], mu_1=popt_qcb[5], sigma_1=popt_qcb[6], alpha_1=popt_qcb[7], n_1=popt_qcb[8], N_1=popt_qcb[9], mu_2=popt_qcb[10], sigma_2=popt_qcb[11], alpha_2=popt_qcb[12], n_2=popt_qcb[13], N_2=popt_qcb[14], mu_3=popt_qcb[15], sigma_3=popt_qcb[16], alpha_3=popt_qcb[17], n_3=popt_qcb[18], N_3=popt_qcb[19])
    ##### 226Ra Peak
    qcb_fit_mu_0 = round(popt_qcb[0],1)
    qcb_fit_sigma_0 = round(popt_qcb[1],1)
    qcb_fit_alpha_0 = round(popt_qcb[2],1)
    qcb_fit_n_0 = round(popt_qcb[3],1)
    qcb_fit_N_0 = round(popt_qcb[4],1)
    print(qcb_fit_mu_0)
    ##### 222Rn Peak
    qcb_fit_mu_1 = round(popt_qcb[5],1)
    qcb_fit_sigma_1 = round(popt_qcb[6],1)
    qcb_fit_alpha_1 = round(popt_qcb[7],1)
    qcb_fit_n_1 = round(popt_qcb[8],1)
    qcb_fit_N_1 = round(popt_qcb[9],1)
    print(qcb_fit_mu_1)
    ##### 218Po Peak
    qcb_fit_mu_2 = round(popt_qcb[10],1)
    qcb_fit_sigma_2 = round(popt_qcb[11],1)
    qcb_fit_alpha_2 = round(popt_qcb[12],1)
    qcb_fit_n_2 = round(popt_qcb[13],1)
    qcb_fit_N_2 = round(popt_qcb[14],1)
    print(qcb_fit_mu_2)
    print(qcb_fit_N_2)
    ##### 214Po Peak
    qcb_fit_mu_3 = round(popt_qcb[15],1)
    qcb_fit_sigma_3 = round(popt_qcb[16],1)
    qcb_fit_alpha_3 = round(popt_qcb[17],1)
    qcb_fit_n_3 = round(popt_qcb[18],1)
    qcb_fit_N_3 = round(popt_qcb[19],1)
    print(qcb_fit_mu_3)
    print(qcb_fit_N_3)
    #### Generating single Crystal Ball data.
    Ra226_cb_fit_x_values, Ra226_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_0, sigma=qcb_fit_sigma_0, alpha=qcb_fit_alpha_0, n=qcb_fit_n_0, N=qcb_fit_N_0)
    Rn222_cb_fit_x_values, Rn222_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_1, sigma=qcb_fit_sigma_1, alpha=qcb_fit_alpha_1, n=qcb_fit_n_1, N=qcb_fit_N_1)
    Po218_cb_fit_x_values, Po218_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    Po214_cb_fit_x_values, Po214_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)

    ### Generating single Gaussian data
    small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_2, A=5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_2, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    gauss_Po218_x_values, gauss_Po218_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_3, A=5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)
    crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_3, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)
    scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    gauss_Po214_x_values, gauss_Po214_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)

    ### Generating residual data
    res_x_data = []
    res_y_data = []
    for i in range(len(file["adc_channel"])):
        res_x_data.append(file["adc_channel"][i])
        res_y_data.append(file["counts"][i]-quad_crystal_ball_function(x=file["adc_channel"][i], mu_0=qcb_fit_mu_0, sigma_0=qcb_fit_sigma_0, alpha_0=qcb_fit_alpha_0, n_0=qcb_fit_n_0, N_0=qcb_fit_N_0, mu_1=qcb_fit_mu_1, sigma_1=qcb_fit_sigma_1, alpha_1=qcb_fit_alpha_1, n_1=qcb_fit_n_1, N_1=qcb_fit_N_1, mu_2=qcb_fit_mu_2, sigma_2=qcb_fit_sigma_2, alpha_2=qcb_fit_alpha_2, n_2=qcb_fit_n_2, N_2=qcb_fit_N_2, mu_3=qcb_fit_mu_3, sigma_3=qcb_fit_sigma_3, alpha_3=qcb_fit_alpha_3, n_3=qcb_fit_n_3, N_3=qcb_fit_N_3))



##################################################################################
###   Plotting.
##################################################################################

if FLAG_plot == True:

    #######################################################################################################################################
    ###   Defining Figure and Frame
    #######################################################################################################################################
    
    fig=plt.figure(figsize=(21, 10.5), dpi=150)  # <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    if FLAG_plot_residual_canvas == True:
        frame1=fig.add_axes((.1,.3,.8,.6)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))
    else: 
        frame1=fig.add_axes((.1,.1,.8,.8)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))

    #######################################################################################################################################
    ###   Plotting Data
    #######################################################################################################################################
    
    ### Plotting histogram, scatter plot or line plot.
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    
    #plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Quadruple Crystal Ball Fit")
        
    ### Plotting the data itself.
    plt.scatter(file["adc_channel"], file["counts"], marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None, label="$^{226}\mathrm{Ra}$ Spectrum Data")
    
    if FLAG_fits == True:
        
        ### Plotting the quadruple Crystal Ball fit.
        plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="cyan", alpha=1, label="Quadruple Crystal Ball Fit")
    
        ### Plotting the Crystal Ball curves resulting from the quadruple Crystal Ball fit.
        #plt.plot(Ra226_cb_fit_x_values, Ra226_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{226}\mathrm{Ra}$")
        #plt.plot(Rn222_cb_fit_x_values, Rn222_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{222}\mathrm{Rn}$")
        plt.plot(Po218_cb_fit_x_values, Po218_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{218}\mathrm{Po}$")
        plt.plot(Po214_cb_fit_x_values, Po214_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting the relevant gaussians resulting from the quadruple Crystal Ball fit.
        plt.plot(gauss_Po218_x_values, gauss_Po218_y_values, marker=",", linewidth=5, c="blue", alpha=0.75, label="Gaussian Curve: $^{218}\mathrm{Po}$")
        plt.plot(gauss_Po214_x_values, gauss_Po214_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting a gaussian fit for the 214Po Peak (the fit is done only for the right half).
        #plt.plot(gauss_fit_x_values, gauss_fit_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Fit: $\mu_\mathrm{G}=\,$" +str(gauss_fit_mu) +"$,\,\,\sigma_\mathrm{G}=\,$" +str(gauss_fit_sigma))
    
    #######################################################################################################################################
    ###   Axes Settings
    #######################################################################################################################################
    
    ### Title
    title_string = "$\\boldsymbol{^{226}\mathrm{Ra}}$ \\textbf{Spectrum}"
    plt.title(title_string, fontsize=28, pad=15)
    
    ### Axes ---> Labels
        #plt.xlabel("\\textbf{$\\boldsymbol{F=ma}$}", fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    xaxisstring = "\\textbf{Energy }$\\boldsymbol{[\\mathrm{adc}]}$"
    yaxisstring = "\\textbf{Counts}"
    if FLAG_plot_residual_canvas == True:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    else:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel(yaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    
    ### Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
        
    ### Axes ---> Range  
    plt.xlim(2000,9600)
    plt.ylim(0,200)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    
    ### Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    if FLAG_plot_residual_canvas == True:
        plt.setp(axes.get_xticklabels(), visible=False)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([])
    
    ### Axes ---> Shading
    #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
    
    ### Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    #######################################################################################################################################
    ###   Colorbar
    #######################################################################################################################################
    
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    #######################################################################################################################################
    ###   Plot Size
    #######################################################################################################################################
    
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.80, top=0.93, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    #######################################################################################################################################
    ###   Legend
    #######################################################################################################################################
    
    if FLAG_legend == True:
    
        if FLAG_plot_residual_canvas == True:
            handles, labels = plt.gca().get_legend_handles_labels()
            order = [5,0,1,3,2,4]
            leg = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=3, bbox_to_anchor=(0.69,0.51), fontsize = 18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
        else:
            leg = plt.legend(loc=3, bbox_to_anchor=(0.68,0.71), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
            
        for line in leg.get_lines(): # enumerated
            line.set_linewidth(4)
        leg.get_frame().set_linewidth(2.5)
        for lh in leg.legendHandles: 
            lh.set_alpha(1)

    #######################################################################################################################################
    ###   Text
    #######################################################################################################################################
    
        plt.text(0.29, 0.82, "$^{226}\mathrm{Ra}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.39, 0.90, "$^{222}\mathrm{Rn}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.54, 0.57, "$^{218}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.80, 0.42, "$^{214}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
        
    if FLAG_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.02, 0.30, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        else:
            plt.text(0.02, 0.450, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        
    #######################################################################################################################################
    ###   Residual Canvas
    #######################################################################################################################################
    
    if FLAG_plot_residual_canvas == True:
        frame2=fig.add_axes((.1,.1,.8,.2))
    
        # Plotting
        plt.scatter(res_x_data, res_y_data, marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None)#, label="Residuals")
    
        # Axes Settings
        plt.ylabel("\\textbf{Residuals}", fontsize=24, labelpad = 9)   # <--- Specifying the x-axis label along with its (self explaining) properties.
        axes2 = plt.gca()
        axes2.tick_params(axis='both')
        for axis in ['top','bottom','left','right']:
            axes2.spines[axis].set_linewidth(2.2)
        ## Axes ---> Range  
        plt.xlim(1000,8500)
        plt.ylim(-150,+150)
        #plt.yscale("log")
        # Axes ---> Ticks
        axes2.xaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
        axes2.yaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
        plt.yticks([-100,0,100])
        #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
        # Axes ---> Shading
        #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
        # Axes ---> Horizontal/Vertical Lines
        #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
        #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)
        axes2.axhline(y=0.0, xmin=0, xmax=10000, color="black", linestyle="--", linewidth=2.0)
    
    #######################################################################################################################################
    ###   Saving
    #######################################################################################################################################
    
    if FLAG_save == True:
        save_string = "spectrum_plot_collection_voltage_0"
        format_string = ".png"
        fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)
# Out:
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
#
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in double_scalars
# 4025.2
# 5077.7
# 6007.9
# 83.6
# 8589.8
# 87.6
# source: $^{226}\mathrm{Ra}$ (masked, in air)\\[0.4cm]
# readout: MCA (.css file: 20190310)\\[0.4cm]
# collection voltage: $U_{\mathrm{coll}}=-0\,\mathrm{V}$\\[0.4cm]
# bias voltage: $U_{\mathrm{bias}}=9\,\mathrm{V}$\\[0.4cm]
# amplifier: v3.1\\[0.4cm]
# vessel: PastaPot\\[0.55cm]
# date: 20190315\\[0.4cm]

# %% [markdown]
# $U_{\mathrm{coll}}=1000\,\mathrm{V}$

# %%
# This function is used to retrieve the energy channel relation utilizing the mean positions (in adc) of two peaks of known energy.
# The inputs "energy_channel_list_1" and "energy_channel_list_1" are list of the form [energy_value, channel_value].
# The function then outputs the adc channel value for the input "energy_value" specified.
def energy_channel_relation(energy_channel_list_high, energy_channel_list_low, energy_value):
    ### Assuming a linear energy_channel_relation the relation E = m*ch+t is used.
    delta_E = energy_channel_list_high[0] - energy_channel_list_low[0]
    delta_ch = energy_channel_list_high[1] - energy_channel_list_low[1]
    m = delta_ch/delta_E
    ### t = E - m*ch
    t = energy_channel_list_high[1] - (m*energy_channel_list_high[0])
    channel_value = m*energy_value +t
    return channel_value

# %%
txt_filestring = "20190315_226Ra_spectrum__226Ra_spectrum__source_226Ramasked_readout_MCA20190310_amp_v3.1_vessel_PastaPot_coll_1000_bias_9.txt"

FLAG_plot = True

FLAG_fits = True
FLAG_text = True
FLAG_legend = True
FLAG_plot_residual_canvas = True
FLAG_save = True


##################################################################################
###   Loading the .txt File.
##################################################################################

file = np.load(save_and_get_histogram_data_as_np_array_from_file(filestring=txt_filestring))



##################################################################################
###   Fitting
##################################################################################

if FLAG_fits == True:

    ### Gaussian fit.
    #### Fitting.
    #popt_gauss, pcov_gauss = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=7300, x_max=7900, function=gauss_function, guess=(1,7300,100))
    #### Generating plottable lists.
    #gauss_fit_x_values, gauss_fit_y_values = get_function_values_for_plot(x_min=6000, x_max=9000, stepwidth=1, function=gauss_function, A=popt_gauss[0], mu=popt_gauss[1], sigma=popt_gauss[2])
    #### Reading out fit parameters.
    #gauss_fit_mu = round(popt_gauss[1],1)
    #gauss_fit_sigma = round(popt_gauss[2],1)

    ### Quadruple Crystal Ball fit.
    #### Fitting.
    popt_qcb, pcov_qcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=1000, x_max=8500, function=quad_crystal_ball_function_vec_self, guess=(3500, 200, 1, 1, 150, 4400, 200, 1, 1, 150, 5300, 200, 1, 1, 150, 7400, 200, 1, 1, 150))
    #### Generating plottable data lists.
    qcb_fit_x_values, qcb_fit_y_values = get_function_values_for_plot(x_min=500, x_max=10000, stepwidth=1, function=quad_crystal_ball_function, mu_0=popt_qcb[0], sigma_0=popt_qcb[1], alpha_0=popt_qcb[2], n_0=popt_qcb[3], N_0=popt_qcb[4], mu_1=popt_qcb[5], sigma_1=popt_qcb[6], alpha_1=popt_qcb[7], n_1=popt_qcb[8], N_1=popt_qcb[9], mu_2=popt_qcb[10], sigma_2=popt_qcb[11], alpha_2=popt_qcb[12], n_2=popt_qcb[13], N_2=popt_qcb[14], mu_3=popt_qcb[15], sigma_3=popt_qcb[16], alpha_3=popt_qcb[17], n_3=popt_qcb[18], N_3=popt_qcb[19])
    ##### 226Ra Peak
    qcb_fit_mu_0 = round(popt_qcb[0],1)
    qcb_fit_sigma_0 = round(popt_qcb[1],1)
    qcb_fit_alpha_0 = round(popt_qcb[2],1)
    qcb_fit_n_0 = round(popt_qcb[3],1)
    qcb_fit_N_0 = round(popt_qcb[4],1)
    ##### 222Rn Peak
    qcb_fit_mu_1 = round(popt_qcb[5],1)
    qcb_fit_sigma_1 = round(popt_qcb[6],1)
    qcb_fit_alpha_1 = round(popt_qcb[7],1)
    qcb_fit_n_1 = round(popt_qcb[8],1)
    qcb_fit_N_1 = round(popt_qcb[9],1)
    ##### 218Po Peak
    qcb_fit_mu_2 = round(popt_qcb[10],1)
    qcb_fit_sigma_2 = round(popt_qcb[11],1)
    qcb_fit_alpha_2 = round(popt_qcb[12],1)
    qcb_fit_n_2 = round(popt_qcb[13],1)
    qcb_fit_N_2 = round(popt_qcb[14],1)
    ##### 214Po Peak
    qcb_fit_mu_3 = round(popt_qcb[15],1)
    qcb_fit_sigma_3 = round(popt_qcb[16],1)
    qcb_fit_alpha_3 = round(popt_qcb[17],1)
    qcb_fit_n_3 = round(popt_qcb[18],1)
    qcb_fit_N_3 = round(popt_qcb[19],1)
    ##### 214Po Peak    #### Generating single Crystal Ball data.
    Ra226_cb_fit_x_values, Ra226_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_0, sigma=qcb_fit_sigma_0, alpha=qcb_fit_alpha_0, n=qcb_fit_n_0, N=qcb_fit_N_0)
    Rn222_cb_fit_x_values, Rn222_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_1, sigma=qcb_fit_sigma_1, alpha=qcb_fit_alpha_1, n=qcb_fit_n_1, N=qcb_fit_N_1)
    Po218_cb_fit_x_values, Po218_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    Po214_cb_fit_x_values, Po214_cb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)

    ### Generating single Gaussian data
    #small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_2, A=5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    #crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_2, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    #scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    #gauss_Po218_x_values, gauss_Po218_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    #small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_3, A=5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)
    #crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_3, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)
    #scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    #gauss_Po214_x_values, gauss_Po214_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)

    ### Generating residual data
    res_x_data = []
    res_y_data = []
    for i in range(len(file["adc_channel"])):
        res_x_data.append(file["adc_channel"][i])
        res_y_data.append((file["counts"][i]-quad_crystal_ball_function(x=file["adc_channel"][i], mu_0=qcb_fit_mu_0, sigma_0=qcb_fit_sigma_0, alpha_0=qcb_fit_alpha_0, n_0=qcb_fit_n_0, N_0=qcb_fit_N_0, mu_1=qcb_fit_mu_1, sigma_1=qcb_fit_sigma_1, alpha_1=qcb_fit_alpha_1, n_1=qcb_fit_n_1, N_1=qcb_fit_N_1, mu_2=qcb_fit_mu_2, sigma_2=qcb_fit_sigma_2, alpha_2=qcb_fit_alpha_2, n_2=qcb_fit_n_2, N_2=qcb_fit_N_2, mu_3=qcb_fit_mu_3, sigma_3=qcb_fit_sigma_3, alpha_3=qcb_fit_alpha_3, n_3=qcb_fit_n_3, N_3=qcb_fit_N_3))/np.sqrt(file["counts"][i]))

    ### Energy Channel Relation
    #### The energy channel relation within these few lines of code are inferred solely from the 214Po and 218Po peaks.
    #### The reasonning behind this is to check, whether the peaks of 226Ra and 222Rn show up where one would expect them to.
    energy_214Po_alpha = 7833.46
    energy_218Po_alpha = 6114.68
    energy_222Rn_alpha = 5590.3
    energy_226Ra_alpha = 4870.62
    energy_channel_214Po_alpha = [energy_214Po_alpha, qcb_fit_mu_3]
    energy_channel_218Po_alpha = [energy_218Po_alpha, qcb_fit_mu_2]
    
        
    ### Printing Analysis Results
    print("Fit Data for the 226Ra Peak: mu_0={}adc, sigma_0={}adc, alpha_0={}, n_0={}, N_0={}".format(qcb_fit_mu_0, qcb_fit_sigma_0, qcb_fit_alpha_0, qcb_fit_n_0, qcb_fit_N_0))
    print("Fit Data for the 222Rn Peak: mu_1={}adc, sigma_1={}adc, alpha_1={}, n_1={}, N_1={}".format(qcb_fit_mu_1, qcb_fit_sigma_1, qcb_fit_alpha_1, qcb_fit_n_1, qcb_fit_N_1))
    print("Fit Data for the 218Po Peak: mu_2={}adc, sigma_2={}adc, alpha_2={}, n_2={}, N_2={}".format(qcb_fit_mu_2, qcb_fit_sigma_2, qcb_fit_alpha_2, qcb_fit_n_2, qcb_fit_N_2))    
    print("Fit Data for the 214Po Peak: mu_3={}adc, sigma_3={}adc, alpha_3={}, n_3={}, N_3={}".format(qcb_fit_mu_3, qcb_fit_sigma_3, qcb_fit_alpha_3, qcb_fit_n_3, qcb_fit_N_3))
    ch_value_226Ra = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_226Ra_alpha)
    ch_value_222Rn = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_222Rn_alpha)
    print("The channels corresponding to the 226Ra ({}keV) and 222Rn ({}keV) peak respectively are {} adc and {} adc.".format(energy_226Ra_alpha, energy_222Rn_alpha, ch_value_226Ra, ch_value_222Rn))
# Out:
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
#
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in double_scalars
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: divide by zero encountered in double_scalars
# Fit Data for the 226Ra Peak: mu_0=3521.7adc, sigma_0=279.3adc, alpha_0=0.3, n_0=4.4, N_0=47.9
# Fit Data for the 222Rn Peak: mu_1=4465.7adc, sigma_1=317.9adc, alpha_1=0.2, n_1=67.0, N_1=104.3
# Fit Data for the 218Po Peak: mu_2=5335.2adc, sigma_2=278.0adc, alpha_2=0.2, n_2=32.8, N_2=88.2
# Fit Data for the 214Po Peak: mu_3=7628.0adc, sigma_3=255.4adc, alpha_3=0.6, n_3=3.5, N_3=101.2
# The channels corresponding to the 226Ra (4870.62keV) and 222Rn (5590.3keV) peak respectively are 3675.6619741909944 adc and 4635.693103247651 adc.

# %%
### Energy Channel Relation
#### The energy channel relation within these few lines of code are inferred solely from the 214Po and 218Po peaks.
#### The reasonning behind this is to check, whether the peaks of 226Ra and 222Rn show up where one would expect them to.
energy_210Po_alpha = 5407.45
energy_214Po_alpha = 7686.82 #7833.46 #
energy_218Po_alpha = 6114.68
energy_222Rn_alpha = 5590.3
energy_226Ra_alpha = 4870.62
energy_channel_214Po_alpha = [energy_214Po_alpha, qcb_fit_mu_3]
energy_channel_218Po_alpha = [energy_218Po_alpha, qcb_fit_mu_2]

ch_value_210Po = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_210Po_alpha)
ch_value_214Po = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_214Po_alpha)
ch_value_218Po = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_218Po_alpha)
ch_value_226Ra = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_226Ra_alpha)
ch_value_222Rn = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_222Rn_alpha)
print()

# %%
### Energy Channel Relation
#### The energy channel relation within these few lines of code are inferred solely from the 214Po and 218Po peaks.
#### The reasonning behind this is to check, whether the peaks of 226Ra and 222Rn show up where one would expect them to.
energy_210Po_alpha = 5407.45
energy_214Po_alpha = 7686.82 #7833.46 #
energy_218Po_alpha = 6114.68
energy_222Rn_alpha = 5590.3
energy_226Ra_alpha = 4870.62
energy_channel_214Po_alpha = [energy_214Po_alpha, qcb_fit_mu_3]
energy_channel_218Po_alpha = [energy_218Po_alpha, qcb_fit_mu_2]

ch_value_210Po = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_210Po_alpha)
ch_value_214Po = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_214Po_alpha)
ch_value_218Po = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_218Po_alpha)
ch_value_226Ra = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_226Ra_alpha)
ch_value_222Rn = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_222Rn_alpha)
    

##################################################################################
###   Plotting.
##################################################################################

FLAG_plot = True
if FLAG_plot == True:
    print("kdföa")
    #######################################################################################################################################
    ###   Defining Figure and Frame
    #######################################################################################################################################
    print("testing")
    fig=plt.figure(figsize=(21, 10.5), dpi=150)  ### <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    
    print("I was here")
    if FLAG_plot_residual_canvas == True:
        print("daniel was here")
        frame1=fig.add_axes((.1,.3,.8,.6)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))
    else:
        frame1=fig.add_axes((.1,.1,.8,.8)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))

    #######################################################################################################################################
    ###   Plotting Data
    #######################################################################################################################################
    
    ### Plotting histogram, scatter plot or line plot.
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    
    #plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Quadruple Crystal Ball Fit")
        
    ### Plotting the data itself.
    plt.scatter(file["adc_channel"], file["counts"], marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None, label="$^{226}\mathrm{Ra}$ Spectrum Data")
    
    if FLAG_fits == True:
        
        ### Plotting the quadruple Crystal Ball fit.
        plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="cyan", alpha=1, label="Quadruple Crystal Ball Fit")
    
        ### Plotting the Crystal Ball curves resulting from the quadruple Crystal Ball fit.
        plt.plot(Ra226_cb_fit_x_values, Ra226_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{226}\mathrm{Ra}$")
        plt.plot(Rn222_cb_fit_x_values, Rn222_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{222}\mathrm{Rn}$")
        plt.plot(Po218_cb_fit_x_values, Po218_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{218}\mathrm{Po}$")
        plt.plot(Po214_cb_fit_x_values, Po214_cb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting the relevant gaussians resulting from the quadruple Crystal Ball fit.
        #plt.plot(gauss_Po218_x_values, gauss_Po218_y_values, marker=",", linewidth=5, c="blue", alpha=0.75, label="Gaussian Curve: $^{218}\mathrm{Po}$")
        #plt.plot(gauss_Po214_x_values, gauss_Po214_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting a gaussian fit for the 214Po Peak (the fit is done only for the right half).
        #plt.plot(gauss_fit_x_values, gauss_fit_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Fit: $\mu_\mathrm{G}=\,$" +str(gauss_fit_mu) +"$,\,\,\sigma_\mathrm{G}=\,$" +str(gauss_fit_sigma))
    
    #######################################################################################################################################
    ###   Axes Settings
    #######################################################################################################################################
    
    ### Title
    title_string = "$\\boldsymbol{^{226}\mathrm{Ra}}$ \\textbf{Spectrum}"
    plt.title(title_string, fontsize=28, pad=15)
    
    ### Axes ---> Labels
        #plt.xlabel("\\textbf{$\\boldsymbol{F=ma}$}", fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    xaxisstring = "\\textbf{Energy }$\\boldsymbol{[\\mathrm{adc}]}$"
    yaxisstring = "\\textbf{Counts}"
    if FLAG_plot_residual_canvas == True:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    else:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel(yaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    
    ### Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
        
    ### Axes ---> Range  
    plt.xlim(2000,8500) #plt.xlim(0,8500)
    plt.ylim(0,200)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    
    ### Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    if FLAG_plot_residual_canvas == True:
        plt.setp(axes.get_xticklabels(), visible=False)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([])
    
    ### Axes ---> Shading
    plt.axvline(x=ch_value_218Po)
    plt.axvline(x=ch_value_214Po)
    plt.axvline(x=ch_value_210Po)
    plt.axvline(x=ch_value_226Ra)
    plt.axvline(x=ch_value_222Rn)
    axes.axvspan(ch_value_218Po-50, ch_value_218Po+50, alpha=0.5, color='0.8')
    axes.axvspan(ch_value_214Po-50, ch_value_214Po+50, alpha=0.5, color='0.8')
    axes.axvspan(ch_value_226Ra-50, ch_value_226Ra+50, alpha=0.5, color='0.8')
    axes.axvspan(ch_value_222Rn-50, ch_value_222Rn+50, alpha=0.5, color='0.8')
    axes.axvspan(ch_value_210Po-50, ch_value_210Po+50, alpha=0.5, color='0.8')
    ### Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    #######################################################################################################################################
    ###   Colorbar
    #######################################################################################################################################
    
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    #######################################################################################################################################
    ###   Plot Size
    #######################################################################################################################################
    
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.80, top=0.93, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    #######################################################################################################################################
    ###   Legend
    #######################################################################################################################################
    
    if FLAG_legend == True:
    
        if FLAG_plot_residual_canvas == True:
            handles, labels = plt.gca().get_legend_handles_labels()
            order = [5,0,1,3,2,4]
            leg = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=3, bbox_to_anchor=(0.69,0.51), fontsize = 18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
        else:
            leg = plt.legend(loc=3, bbox_to_anchor=(0.68,0.71), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
            
        for line in leg.get_lines(): # enumerated
            line.set_linewidth(4)
        leg.get_frame().set_linewidth(2.5)
        for lh in leg.legendHandles: 
            lh.set_alpha(1)

    #######################################################################################################################################
    ###   Text
    #######################################################################################################################################
    
        plt.text(0.29, 0.82, "$^{226}\mathrm{Ra}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.39, 0.90, "$^{222}\mathrm{Rn}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.54, 0.57, "$^{218}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
        plt.text(0.80, 0.42, "$^{214}\mathrm{Po}$", fontsize=22, transform = axes.transAxes)
        
    if FLAG_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.02, 0.30, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        else:
            plt.text(0.02, 0.450, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        
    #######################################################################################################################################
    ###   Residual Canvas
    #######################################################################################################################################
    
    if FLAG_plot_residual_canvas == True:
        frame2=fig.add_axes((.1,.1,.8,.2))
    
        # Plotting
        plt.scatter(res_x_data, res_y_data, marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None)#, label="Residuals")
    
        # Axes Settings
        plt.ylabel("\\textbf{Residuals} $[\\mathrm{\\sigma}]$", fontsize=24, labelpad = 9)   # <--- Specifying the x-axis label along with its (self explaining) properties.
        axes2 = plt.gca()
        axes2.tick_params(axis='both')
        for axis in ['top','bottom','left','right']:
            axes2.spines[axis].set_linewidth(2.2)
        ## Axes ---> Range  
        plt.xlim(2000,8500)
        plt.ylim(-4,+4)
        #plt.yscale("log")
        # Axes ---> Ticks
        axes2.xaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
        axes2.yaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
        plt.yticks([-3,0,3])
        #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
        # Axes ---> Shading
        #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
        # Axes ---> Horizontal/Vertical Lines
        #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
        #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)
        axes2.axhline(y=0.0, xmin=0, xmax=10000, color="black", linestyle="--", linewidth=2.0)
    
    #######################################################################################################################################
    ###   Saving
    #######################################################################################################################################
    
    if FLAG_save == True:
        save_string = "spectrum_plot_collection_voltage_1000"
        format_string = ".png"
        fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)
# Out:
# kdföa
# testing
# I was here
# daniel was here
# source: $^{226}\mathrm{Ra}$ (masked, in air)\\[0.4cm]
# readout: MCA (.css file: 20190310)\\[0.4cm]
# collection voltage: $U_{\mathrm{coll}}=-1000\,\mathrm{V}$\\[0.4cm]
# bias voltage: $U_{\mathrm{bias}}=9\,\mathrm{V}$\\[0.4cm]
# amplifier: v3.1\\[0.4cm]
# vessel: PastaPot\\[0.55cm]
# date: 20190315\\[0.4cm]

# %%
# Out:
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in double_scalars
#
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in double_scalars
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
#
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in double_scalars
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:93: RuntimeWarning: divide by zero encountered in double_scalars
# Fit Data for the 226Ra Peak: mu_0=3521.7adc, sigma_0=279.3adc, alpha_0=0.3, n_0=4.4, N_0=47.9
# Fit Data for the 222Rn Peak: mu_1=4465.7adc, sigma_1=317.9adc, alpha_1=0.2, n_1=67.0, N_1=104.3
# Fit Data for the 218Po Peak: mu_2=5335.2adc, sigma_2=278.0adc, alpha_2=0.2, n_2=32.8, N_2=88.2
# Fit Data for the 214Po Peak: mu_3=7628.0adc, sigma_3=255.4adc, alpha_3=0.6, n_3=3.5, N_3=101.2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-229-7c233b6fc907> in <module>
#     109     print("Fit Data for the 218Po Peak: mu_2={}adc, sigma_2={}adc, alpha_2={}, n_2={}, N_2={}".format(qcb_fit_mu_2, qcb_fit_sigma_2, qcb_fit_alpha_2, qcb_fit_n_2, qcb_fit_N_2))
#     110     print("Fit Data for the 214Po Peak: mu_3={}adc, sigma_3={}adc, alpha_3={}, n_3={}, N_3={}".format(qcb_fit_mu_3, qcb_fit_sigma_3, qcb_fit_alpha_3, qcb_fit_n_3, qcb_fit_N_3))
# --> 111     print("Fit Data for the 210Po Peak: mu_4={}adc, sigma_4={}adc, alpha_4={}, n_4={}, N_4={}".format(qcb_fit_mu_4, qcb_fit_sigma_4, qcb_fit_alpha_4, qcb_fit_n_4, qcb_fit_N_4))
#     112     ch_value_226Ra = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_226Ra_alpha)
#     113     ch_value_222Rn = energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_222Rn_alpha)
#
# NameError: name 'qcb_fit_mu_4' is not defined

# %%
print("214Po")
print(energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_214Po_alpha))

print("218Po")
print(energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_218Po_alpha))

print("222Rn")
print(energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_222Rn_alpha))

print("210Po")
print(energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_210Po_alpha))

print("226Ra")
print(energy_channel_relation(energy_channel_list_high=energy_channel_214Po_alpha, energy_channel_list_low=energy_channel_218Po_alpha, energy_value=energy_226Ra_alpha))
# Out:
# 214Po
# 7628.0
# 218Po
# 5332.6
# 222Rn
# 4633.720353583026
# 210Po
# 4381.419445879119
# 226Ra
# 3672.837490724085

# %%
txt_filestring = "20190315_226Ra_spectrum__226Ra_spectrum__source_226Ramasked_readout_MCA20190310_amp_v3.1_vessel_PastaPot_coll_1000_bias_9.txt"

FLAG_plot = True

FLAG_fits = True
FLAG_analysis = True
FLAG_setup_text = False
FLAG_peak_text = True
FLAG_legend = False
FLAG_plot_residual_canvas = True
FLAG_save = True

if FLAG_fits == False:
    FLAG_peak_text = False
    FLAG_legend = False

# %%
##################################################################################
###   Loading the .txt File.
##################################################################################

file = np.load(save_and_get_histogram_data_as_np_array_from_file(filestring=txt_filestring))



##################################################################################
###   Fitting
##################################################################################

if FLAG_fits == True:

    ### Gaussian fit.
    #### Fitting.
    #popt_gauss, pcov_gauss = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=7300, x_max=7900, function=gauss_function, guess=(1,7300,100))
    #### Generating plottable lists.
    #gauss_fit_x_values, gauss_fit_y_values = get_function_values_for_plot(x_min=6000, x_max=9000, stepwidth=1, function=gauss_function, A=popt_gauss[0], mu=popt_gauss[1], sigma=popt_gauss[2])
    #### Reading out fit parameters.
    #gauss_fit_mu = round(popt_gauss[1],1)
    #gauss_fit_sigma = round(popt_gauss[2],1)

    ### Quadruple Crystal Ball fit.
    #### Fitting.
    #popt_quintcb, pcov_quintcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=1000, x_max=8500, function=quint_crystal_ball_function_vec_self, guess=(3520, 280, 0.3, 4.4, 50, ch_value_222Rn, 300, 0.2, 65, 100, 5330, 275, 0.2, 30, 85, 7628, 255, 0.6, 3.5, 101, ch_value_210Po, 270, 1, 1, 50))
    popt_quintcb, pcov_quintcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=1000, x_max=8500, function=quint_crystal_ball_function_vec_self, guess=(3672, 280, 0.3, 4.4, 50, 4633, 300, 0.2, 65, 100, 5332, 275, 0.2, 30, 85, 7628, 255, 0.6, 3.5, 101, 4381, 270, 1, 1, 50))
    #### Generating plottable data lists.
    quintcb_fit_x_values, quintcb_fit_y_values = get_function_values_for_plot(x_min=500, x_max=10000, stepwidth=1, function=quint_crystal_ball_function, mu_0=popt_quintcb[0], sigma_0=popt_quintcb[1], alpha_0=popt_quintcb[2], n_0=popt_quintcb[3], N_0=popt_quintcb[4], mu_1=popt_quintcb[5], sigma_1=popt_quintcb[6], alpha_1=popt_quintcb[7], n_1=popt_quintcb[8], N_1=popt_quintcb[9], mu_2=popt_quintcb[10], sigma_2=popt_quintcb[11], alpha_2=popt_quintcb[12], n_2=popt_quintcb[13], N_2=popt_quintcb[14], mu_3=popt_quintcb[15], sigma_3=popt_quintcb[16], alpha_3=popt_quintcb[17], n_3=popt_quintcb[18], N_3=popt_quintcb[19], mu_4=popt_quintcb[20], sigma_4=popt_quintcb[21], alpha_4=popt_quintcb[22], n_4=popt_quintcb[23], N_4=popt_quintcb[24])
    ##### 226Ra Peak
    quintcb_fit_mu_0 = popt_quintcb[0]
    quintcb_fit_sigma_0 = popt_quintcb[1]
    quintcb_fit_alpha_0 = popt_quintcb[2]
    quintcb_fit_n_0 = popt_quintcb[3]
    quintcb_fit_N_0 = popt_quintcb[4]
    ##### 222Rn Peak
    quintcb_fit_mu_1 = popt_quintcb[5]
    quintcb_fit_sigma_1 = popt_quintcb[6]
    quintcb_fit_alpha_1 = popt_quintcb[7]
    quintcb_fit_n_1 = popt_quintcb[8]
    quintcb_fit_N_1 = popt_quintcb[9]
    ##### 218Po Peak
    quintcb_fit_mu_2 = popt_quintcb[10]
    quintcb_fit_sigma_2 = popt_quintcb[11]
    quintcb_fit_alpha_2 = popt_quintcb[12]
    quintcb_fit_n_2 = popt_quintcb[13]
    quintcb_fit_N_2 = popt_quintcb[14]
    ##### 214Po Peak
    quintcb_fit_mu_3 = popt_quintcb[15]
    quintcb_fit_sigma_3 = popt_quintcb[16]
    quintcb_fit_alpha_3 = popt_quintcb[17]
    quintcb_fit_n_3 = popt_quintcb[18]
    quintcb_fit_N_3 = popt_quintcb[19]
    ##### 210Po Peak
    quintcb_fit_mu_4 = popt_quintcb[20]
    quintcb_fit_sigma_4 = popt_quintcb[21]
    quintcb_fit_alpha_4 = popt_quintcb[22]
    quintcb_fit_n_4 = popt_quintcb[23]
    quintcb_fit_N_4 = popt_quintcb[24]
    #### Generating single Crystal Ball data.
    Ra226_quintcb_fit_x_values, Ra226_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_0, sigma=quintcb_fit_sigma_0, alpha=quintcb_fit_alpha_0, n=quintcb_fit_n_0, N=quintcb_fit_N_0)
    Rn222_quintcb_fit_x_values, Rn222_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1)
    Po218_quintcb_fit_x_values, Po218_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_2, sigma=quintcb_fit_sigma_2, alpha=quintcb_fit_alpha_2, n=quintcb_fit_n_2, N=quintcb_fit_N_2)
    Po214_quintcb_fit_x_values, Po214_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_3, sigma=quintcb_fit_sigma_3, alpha=quintcb_fit_alpha_3, n=quintcb_fit_n_3, N=quintcb_fit_N_3)
    Po210_quintcb_fit_x_values, Po210_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4)
    print("Quintuple Crystal Ball fit successfully executed")
    
    ### Generating single Gaussian data
    #small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_2, A=5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    #crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_2, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    #scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    #gauss_Po218_x_values, gauss_Po218_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    #small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_3, A=5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)
    #crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_3, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)
    #scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    #gauss_Po214_x_values, gauss_Po214_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)

    ### Generating residual data
    res_x_data = []
    res_y_data = []
    for i in range(len(file["adc_channel"])):
        res_x_data.append(file["adc_channel"][i])
        res_y_data.append((file["counts"][i]-quint_crystal_ball_function(x=file["adc_channel"][i], mu_0=quintcb_fit_mu_0, sigma_0=quintcb_fit_sigma_0, alpha_0=quintcb_fit_alpha_0, n_0=quintcb_fit_n_0, N_0=quintcb_fit_N_0, mu_1=quintcb_fit_mu_1, sigma_1=quintcb_fit_sigma_1, alpha_1=quintcb_fit_alpha_1, n_1=quintcb_fit_n_1, N_1=quintcb_fit_N_1, mu_2=quintcb_fit_mu_2, sigma_2=quintcb_fit_sigma_2, alpha_2=quintcb_fit_alpha_2, n_2=quintcb_fit_n_2, N_2=quintcb_fit_N_2, mu_3=quintcb_fit_mu_3, sigma_3=quintcb_fit_sigma_3, alpha_3=quintcb_fit_alpha_3, n_3=quintcb_fit_n_3, N_3=quintcb_fit_N_3, mu_4=quintcb_fit_mu_4, sigma_4=quintcb_fit_sigma_4, alpha_4=quintcb_fit_alpha_4, n_4=quintcb_fit_n_4, N_4=quintcb_fit_N_4))/np.sqrt(file["counts"][i]))
    
##################################################################################
###   Analysis
##################################################################################

if FLAG_analysis == True:

    ### Literature values (nucleide.ord) for the respective alpha energies.
    ### Denoted behind is the total Q value of the alpha decay.
    energy_214Po_alpha = 7686.82 #7833.46
    energy_218Po_alpha = 6002.35 #6114.68
    energy_222Rn_alpha = 5489.48 #5590.3
    energy_210Po_alpha = 5304.33 #5407.45
    energy_226Ra_alpha = 4784.34 #4870.62
    
    ### Energy Channel Relation (Inferred from two Peaks)
    #### The energy channel relation within these few lines of code are inferred solely from the 214Po and 218Po peaks.
    #### The reasonning behind this is to check, whether the peaks of 226Ra, 222Rn and 210Po show up where one would expect them to.
    energy_channel_high = [energy_214Po_alpha, quintcb_fit_mu_3]
    energy_channel_low = [energy_218Po_alpha, quintcb_fit_mu_2]
    ch_value_214Po = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_214Po_alpha)
    ch_value_218Po = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_218Po_alpha)
    ch_value_222Rn = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_222Rn_alpha)
    ch_value_210Po = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_210Po_alpha)
    ch_value_226Ra = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_226Ra_alpha)

       
    ### Printing Analysis Results
    print("Fit Data for the 226Ra Peak: mu_0={}adc, sigma_0={}adc, alpha_0={}, n_0={}, N_0={}".format(quintcb_fit_mu_0, quintcb_fit_sigma_0, quintcb_fit_alpha_0, quintcb_fit_n_0, quintcb_fit_N_0))
    print("Fit Data for the 222Rn Peak: mu_1={}adc, sigma_1={}adc, alpha_1={}, n_1={}, N_1={}".format(quintcb_fit_mu_1, quintcb_fit_sigma_1, quintcb_fit_alpha_1, quintcb_fit_n_1, quintcb_fit_N_1))
    print("Fit Data for the 218Po Peak: mu_2={}adc, sigma_2={}adc, alpha_2={}, n_2={}, N_2={}".format(quintcb_fit_mu_2, quintcb_fit_sigma_2, quintcb_fit_alpha_2, quintcb_fit_n_2, quintcb_fit_N_2))    
    print("Fit Data for the 214Po Peak: mu_3={}adc, sigma_3={}adc, alpha_3={}, n_3={}, N_3={}".format(quintcb_fit_mu_3, quintcb_fit_sigma_3, quintcb_fit_alpha_3, quintcb_fit_n_3, quintcb_fit_N_3))
    print("Fit Data for the 210Po Peak: mu_4={}adc, sigma_4={}adc, alpha_4={}, n_4={}, N_4={}".format(quintcb_fit_mu_4, quintcb_fit_sigma_4, quintcb_fit_alpha_4, quintcb_fit_n_4, quintcb_fit_N_4))
    print("The channels corresponding to the 226Ra ({}keV), 210Po ({}keV) and 222Rn ({}keV) peak respectively are {} adc and {} adc.".format(energy_226Ra_alpha, energy_210Po_alpha, energy_222Rn_alpha, ch_value_226Ra, ch_value_210Po, ch_value_222Rn))
# Out:
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in double_scalars
#
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in double_scalars
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
#
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in double_scalars
# Quintuple Crystal Ball fit successfully executed
# /scratch/db1086/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:84: RuntimeWarning: divide by zero encountered in double_scalars
# Fit Data for the 226Ra Peak: mu_0=3522.4970423518175adc, sigma_0=314.2924101461813adc, alpha_0=0.3357527551711467, n_0=5.524076234496855, N_0=49.63362208834851
# Fit Data for the 222Rn Peak: mu_1=4520.6973003200565adc, sigma_1=280.76948244140686adc, alpha_1=0.18757598233013528, n_1=89.95038552983985, N_1=90.51638009796218
# Fit Data for the 218Po Peak: mu_2=5328.317882554588adc, sigma_2=281.0700214538262adc, alpha_2=0.17420825221476582, n_2=109.45171641085179, N_2=89.57305961777377
# Fit Data for the 214Po Peak: mu_3=7628.0999799512265adc, sigma_3=255.34956710708133adc, alpha_3=0.5683249656264424, n_3=3.502586537362637, N_3=101.24736519400572
# Fit Data for the 210Po Peak: mu_4=4358.70461403892adc, sigma_4=141.77139003434468adc, alpha_4=1.6979849178338502, n_4=1.0625348265327788, N_4=10.71308035439671
# The channels corresponding to the 226Ra (4784.34keV), 210Po (5304.33keV) and 222Rn (5489.48keV) peak respectively are 3665.386757363829 adc and 4375.32145066515 adc.

# %%
# order of appearance:
# 214Po, 218Po, 222Rn, 210Po, 226Po
energy_list = [7686.82, 6002.35, 5489.48, 5304.33, 4784.34]
channel_list = [quintcb_fit_mu_3, quintcb_fit_mu_2, quintcb_fit_mu_1, quintcb_fit_mu_4, quintcb_fit_mu_0]
sigma_channel_list = [np.sqrt(np.diag(pcov_quintcb))[15], np.sqrt(np.diag(pcov_quintcb))[10], np.sqrt(np.diag(pcov_quintcb))[5], np.sqrt(np.diag(pcov_quintcb))[20], np.sqrt(np.diag(pcov_quintcb))[0]]

popt_lin, pcov_lin = curve_fit(f=linear_function, xdata=energy_list, ydata=channel_list, sigma=sigma_channel_list, absolute_sigma=True, method='lm')

m = popt_lin[0]
sigma_m = np.sqrt(np.diag(pcov_lin))[0]
t = popt_lin[1]
sigma_t = np.sqrt(np.diag(pcov_lin))[1]
print(sigma_m)

erg_channel_list = [0,0,0,0,0]
sigma_erg_channel_list = [0,0,0,0,0]
for i in range(len(erg_channel_list)):
    erg_channel_list[i] = (m*energy_list[i])+t
    sigma_erg_channel_list[i] = np.sqrt(((energy_list[i]*sigma_m)**2)+1)
# Out:
# 0.007889094499934978

# %%
##################################################################################
###   Plotting.
##################################################################################

if FLAG_plot == True:

    #######################################################################################################################################
    ###   Defining Figure and Frame
    #######################################################################################################################################

    fig=plt.figure(figsize=(21, 10.5), dpi=150)  ### <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    
    if FLAG_plot_residual_canvas == True:
        frame1=fig.add_axes((.1,.3,.8,.6)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))
    else:
        frame1=fig.add_axes((.1,.1,.8,.8)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))

    #######################################################################################################################################
    ###   Plotting Data
    #######################################################################################################################################
    
    ### Plotting histogram, scatter plot or line plot.
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    
    #plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Quadruple Crystal Ball Fit")
        
    ### Plotting the data itself.
    plt.scatter(file["adc_channel"], file["counts"], marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None, label="$^{226}\mathrm{Ra}$ Spectrum Data")
    
    if FLAG_fits == True:
        
        ### Plotting the quadruple Crystal Ball fit.
        plt.plot(quintcb_fit_x_values, quintcb_fit_y_values, marker=",", linewidth=5, c="cyan", alpha=1, label="Quintuple Crystal Ball Fit")
    
        ### Plotting the Crystal Ball curves resulting from the quadruple Crystal Ball fit.
        plt.plot(Ra226_quintcb_fit_x_values, Ra226_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{226}\mathrm{Ra}$")
        plt.plot(Rn222_quintcb_fit_x_values, Rn222_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{222}\mathrm{Rn}$")
        plt.plot(Po218_quintcb_fit_x_values, Po218_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{218}\mathrm{Po}$")
        plt.plot(Po214_quintcb_fit_x_values, Po214_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{214}\mathrm{Po}$")
        plt.plot(Po210_quintcb_fit_x_values, Po210_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{210}\mathrm{Po}$")
    
        ### Plotting the relevant gaussians resulting from the quadruple Crystal Ball fit.
        #plt.plot(gauss_Po218_x_values, gauss_Po218_y_values, marker=",", linewidth=5, c="blue", alpha=0.75, label="Gaussian Curve: $^{218}\mathrm{Po}$")
        #plt.plot(gauss_Po214_x_values, gauss_Po214_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting a gaussian fit for the 214Po Peak (the fit is done only for the right half).
        #plt.plot(gauss_fit_x_values, gauss_fit_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Fit: $\mu_\mathrm{G}=\,$" +str(gauss_fit_mu) +"$,\,\,\sigma_\mathrm{G}=\,$" +str(gauss_fit_sigma))
    
    #######################################################################################################################################
    ###   Axes Settings
    #######################################################################################################################################
    
    ### Title
    title_string = "$\\boldsymbol{^{226}\mathrm{Ra}}$ \\textbf{Spectrum}"
    plt.title(title_string, fontsize=28, pad=15)
    
    ### Axes ---> Labels
        #plt.xlabel("\\textbf{$\\boldsymbol{F=ma}$}", fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    xaxisstring = "\\textbf{Energy }$\\boldsymbol{[\\mathrm{adc}]}$"
    yaxisstring = "\\textbf{Counts}"
    if FLAG_plot_residual_canvas == True:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    else:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel(yaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    
    ### Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
        
    ### Axes ---> Range  
    plt.xlim(2000,8500) #plt.xlim(0,8500)
    plt.ylim(0,200)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    
    ### Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    if FLAG_plot_residual_canvas == True:
        plt.setp(axes.get_xticklabels(), visible=False)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([])
    
    ### Axes ---> Shading
    #plt.fill_between(m_1_gummy_bears_1sigma,p_Tab_1_gummy_bears_1sigma, color='yellow',label='$\sigma_{x}$-Intervall')
    #### 214Po
    shade_x_values = np.arange(erg_channel_list[0]-sigma_erg_channel_list[0], erg_channel_list[0]+sigma_erg_channel_list[0], 0.5)
    shade_y_values = []
    for i in range(len(shade_x_values)):
        shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_3, sigma=quintcb_fit_sigma_3, alpha=quintcb_fit_alpha_3, n=quintcb_fit_n_3, N=quintcb_fit_N_3))
    plt.fill_between(x=shade_x_values, y1=shade_y_values, y2=0, color='0.8', alpha=0.5)
    vertical_line_list_x = [erg_channel_list[0], erg_channel_list[0]]
    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[0], mu=quintcb_fit_mu_3, sigma=quintcb_fit_sigma_3, alpha=quintcb_fit_alpha_3, n=quintcb_fit_n_3, N=quintcb_fit_N_3)]
    plt.plot(vertical_line_list_x, vertical_line_list_y, color='black',linewidth=2.2,linestyle='-')
    #### 218Po
    shade_x_values = np.arange(erg_channel_list[1]-sigma_erg_channel_list[1], erg_channel_list[1]+sigma_erg_channel_list[1], 0.5)
    shade_y_values = []
    for i in range(len(shade_x_values)):
        shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_2, sigma=quintcb_fit_sigma_2, alpha=quintcb_fit_alpha_2, n=quintcb_fit_n_2, N=quintcb_fit_N_2))
    plt.fill_between(x=shade_x_values, y1=shade_y_values, y2=0, color='0.8', alpha=0.5)
    vertical_line_list_x = [erg_channel_list[1], erg_channel_list[1]]
    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[1], mu=quintcb_fit_mu_2, sigma=quintcb_fit_sigma_2, alpha=quintcb_fit_alpha_2, n=quintcb_fit_n_2, N=quintcb_fit_N_2)]
    plt.plot(vertical_line_list_x, vertical_line_list_y, color='black',linewidth=2.2,linestyle='-')
    #### 222Rn
    shade_x_values = np.arange(erg_channel_list[2]-sigma_erg_channel_list[2], erg_channel_list[2]+sigma_erg_channel_list[2], 0.5)
    shade_y_values = []
    for i in range(len(shade_x_values)):
        shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1))
    plt.fill_between(x=shade_x_values, y1=shade_y_values, y2=0, color='0.8', alpha=0.5)
    vertical_line_list_x = [erg_channel_list[2], erg_channel_list[2]]
    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[2], mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1)]
    plt.plot(vertical_line_list_x, vertical_line_list_y, color='black',linewidth=2.2,linestyle='-')
    #### 210Po
    shade_x_values = np.arange(erg_channel_list[4]-sigma_erg_channel_list[4], erg_channel_list[4]+sigma_erg_channel_list[4], 0.5)
    shade_y_values = []
    for i in range(len(shade_x_values)):
        shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_0, sigma=quintcb_fit_sigma_0, alpha=quintcb_fit_alpha_0, n=quintcb_fit_n_0, N=quintcb_fit_N_0))
    plt.fill_between(x=shade_x_values, y1=shade_y_values, y2=0, color='0.8', alpha=0.5)
    vertical_line_list_x = [erg_channel_list[4], erg_channel_list[4]]
    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[4], mu=quintcb_fit_mu_0, sigma=quintcb_fit_sigma_0, alpha=quintcb_fit_alpha_0, n=quintcb_fit_n_0, N=quintcb_fit_N_0)]
    plt.plot(vertical_line_list_x, vertical_line_list_y, color='black',linewidth=2.2,linestyle='-')
    #### 226Ra
    shade_x_values = np.arange(erg_channel_list[3]-sigma_erg_channel_list[3], erg_channel_list[3]+sigma_erg_channel_list[3], 0.5)
    shade_y_values = []
    for i in range(len(shade_x_values)):
        shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4))
    plt.fill_between(x=shade_x_values, y1=shade_y_values, y2=0, color='0.8', alpha=0.5)
    vertical_line_list_x = [erg_channel_list[3], erg_channel_list[3]]
    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[3], mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4)]
    plt.plot(vertical_line_list_x, vertical_line_list_y, color='black',linewidth=2.2,linestyle='-')


#
#shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1))
#
#shade_y_values.append(crystal_ball_function(x=shade_x_values[i], mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4))

    
    
    #plt.axvline(x=erg_channel_list[1], color="black")
    #plt.axvline(x=erg_channel_list[2], color="black")
    #plt.axvline(x=erg_channel_list[3], color="black")
    #plt.axvline(x=erg_channel_list[4], color="black")

    #plt.fill_between(x=np.asarray(Po214_quintcb_fit_x_values), y1=np.asarray(Po214_quintcb_fit_y_values), y2=0, where=[np.asarray(Rn222_quintcb_fit_x_values) >= erg_channel_list[0]-sigma_erg_channel_list[0], np.asarray(Po214_quintcb_fit_x_values)<=erg_channel_list[0]+sigma_erg_channel_list[0]], color='yellow')#,label='$\sigma_{x}$-Intervall')
    #axes.axvspan(erg_channel_list[1]-sigma_erg_channel_list[1], erg_channel_list[1]+sigma_erg_channel_list[1], alpha=0.5, color='0.8')
    #axes.axvspan(erg_channel_list[2]-sigma_erg_channel_list[2], erg_channel_list[2]+sigma_erg_channel_list[2], alpha=0.5, color='0.8')
    #axes.axvspan(erg_channel_list[3]-sigma_erg_channel_list[3], erg_channel_list[3]+sigma_erg_channel_list[3], alpha=0.5, color='0.8')
    #axes.axvspan(erg_channel_list[4]-sigma_erg_channel_list[4], erg_channel_list[4]+sigma_erg_channel_list[4], alpha=0.5, color='0.8')
    ### Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    #######################################################################################################################################
    ###   Colorbar
    #######################################################################################################################################
    
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    #######################################################################################################################################
    ###   Plot Size
    #######################################################################################################################################
    
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.80, top=0.93, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    #######################################################################################################################################
    ###   Legend
    #######################################################################################################################################
    
    if FLAG_legend == True:
    
        if FLAG_plot_residual_canvas == True:
            handles, labels = plt.gca().get_legend_handles_labels()
            order = [5,0,1,3,2,4]
            leg = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=3, bbox_to_anchor=(0.69,0.51), fontsize = 18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
        else:
            leg = plt.legend(loc=3, bbox_to_anchor=(0.68,0.71), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
            
        for line in leg.get_lines(): # enumerated
            line.set_linewidth(4)
        leg.get_frame().set_linewidth(2.5)
        for lh in leg.legendHandles: 
            lh.set_alpha(1)

    #######################################################################################################################################
    ###   Text
    #######################################################################################################################################
    
    if FLAG_peak_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.89, 0.54, "$\\boldsymbol{^{214}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)            
            plt.text(0.54, 0.46, "$\\boldsymbol{^{218}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.36, 0.47, "$\\boldsymbol{^{222}\mathrm{Rn}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.32, 0.08, "$\\boldsymbol{^{210}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.19, 0.28, "$\\boldsymbol{^{226}\mathrm{Ra}}$", fontsize=22, transform = axes.transAxes)
        else:
            print("Still got some stuff to do here.")
        
    if FLAG_setup_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.02, 0.35, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        else:
            plt.text(0.02, 0.450, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        
    #######################################################################################################################################
    ###   Residual Canvas
    #######################################################################################################################################
    
    if FLAG_plot_residual_canvas == True:
        frame2=fig.add_axes((.1,.1,.8,.2))
    
        # Plotting
        plt.scatter(res_x_data, res_y_data, marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None)#, label="Residuals")
    
        # Axes Settings
        plt.ylabel("\\textbf{Residuals} $\\boldsymbol{[\\mathrm{\\sigma}]}$", fontsize=24, labelpad = 9)   # <--- Specifying the x-axis label along with its (self explaining) properties.
        axes2 = plt.gca()
        axes2.tick_params(axis='both')
        for axis in ['top','bottom','left','right']:
            axes2.spines[axis].set_linewidth(2.2)
        ## Axes ---> Range  
        plt.xlim(2000,8500)
        plt.ylim(-4,+4)
        #plt.yscale("log")
        # Axes ---> Ticks
        axes2.xaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
        axes2.yaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
        plt.yticks([-2, 0, 2])
        #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
        # Axes ---> Shading
        #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
        # Axes ---> Horizontal/Vertical Lines
        #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
        #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)
        axes2.axhline(y=0.0, xmin=0, xmax=10000, color="black", linestyle="--", linewidth=2.0)
    
    #######################################################################################################################################
    ###   Saving
    #######################################################################################################################################
    
    if FLAG_save == True:
        save_string = "spectrum_plot_collection_voltage_1000"
        format_string = ".png"
        fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)

# %%
txt_filestring = "20190315_226Ra_spectrum__226Ra_spectrum__source_226Ramasked_readout_MCA20190310_amp_v3.1_vessel_PastaPot_coll_1000_bias_9.txt"

FLAG_plot = True

FLAG_fits = False
FLAG_analysis = True
FLAG_setup_text = False
FLAG_peak_text = True
FLAG_legend = False
FLAG_plot_residual_canvas = False
FLAG_save = True

if FLAG_fits == False:
    FLAG_peak_text = False
    FLAG_legend = False

# %%
##################################################################################
###   Loading the .txt File.
##################################################################################

file = np.load(save_and_get_histogram_data_as_np_array_from_file(filestring=txt_filestring))



##################################################################################
###   Fitting
##################################################################################

if FLAG_fits == True:

    ### Gaussian fit.
    #### Fitting.
    #popt_gauss, pcov_gauss = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=7300, x_max=7900, function=gauss_function, guess=(1,7300,100))
    #### Generating plottable lists.
    #gauss_fit_x_values, gauss_fit_y_values = get_function_values_for_plot(x_min=6000, x_max=9000, stepwidth=1, function=gauss_function, A=popt_gauss[0], mu=popt_gauss[1], sigma=popt_gauss[2])
    #### Reading out fit parameters.
    #gauss_fit_mu = round(popt_gauss[1],1)
    #gauss_fit_sigma = round(popt_gauss[2],1)

    ### Quadruple Crystal Ball fit.
    #### Fitting.
    #popt_quintcb, pcov_quintcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=1000, x_max=8500, function=quint_crystal_ball_function_vec_self, guess=(3520, 280, 0.3, 4.4, 50, ch_value_222Rn, 300, 0.2, 65, 100, 5330, 275, 0.2, 30, 85, 7628, 255, 0.6, 3.5, 101, ch_value_210Po, 270, 1, 1, 50))
    popt_quintcb, pcov_quintcb = fit_range_function(x=file["adc_channel"].tolist(),y=file["counts"].tolist(),x_min=1000, x_max=8500, function=quint_crystal_ball_function_vec_self, guess=(3672, 280, 0.3, 4.4, 50, 4381, 270, 1, 1, 50, 4633, 300, 0.2, 65, 100, 5332, 275, 0.2, 30, 85, 7628, 255, 0.6, 3.5, 101))
    #### Generating plottable data lists.
    quintcb_fit_x_values, quintcb_fit_y_values = get_function_values_for_plot(x_min=500, x_max=10000, stepwidth=1, function=quint_crystal_ball_function, mu_0=popt_quintcb[0], sigma_0=popt_quintcb[1], alpha_0=popt_quintcb[2], n_0=popt_quintcb[3], N_0=popt_quintcb[4], mu_1=popt_quintcb[5], sigma_1=popt_quintcb[6], alpha_1=popt_quintcb[7], n_1=popt_quintcb[8], N_1=popt_quintcb[9], mu_2=popt_quintcb[10], sigma_2=popt_quintcb[11], alpha_2=popt_quintcb[12], n_2=popt_quintcb[13], N_2=popt_quintcb[14], mu_3=popt_quintcb[15], sigma_3=popt_quintcb[16], alpha_3=popt_quintcb[17], n_3=popt_quintcb[18], N_3=popt_quintcb[19], mu_4=popt_quintcb[20], sigma_4=popt_quintcb[21], alpha_4=popt_quintcb[22], n_4=popt_quintcb[23], N_4=popt_quintcb[24])
    ##### 226Ra Peak
    quintcb_fit_mu_0 = popt_quintcb[0]
    quintcb_fit_sigma_0 = popt_quintcb[1]
    quintcb_fit_alpha_0 = popt_quintcb[2]
    quintcb_fit_n_0 = popt_quintcb[3]
    quintcb_fit_N_0 = popt_quintcb[4]
    ##### 210Po Peak
    quintcb_fit_mu_1 = popt_quintcb[5]
    quintcb_fit_sigma_1 = popt_quintcb[6]
    quintcb_fit_alpha_1 = popt_quintcb[7]
    quintcb_fit_n_1 = popt_quintcb[8]
    quintcb_fit_N_1 = popt_quintcb[9]
    ##### 222Rn Peak
    quintcb_fit_mu_2 = popt_quintcb[10]
    quintcb_fit_sigma_2 = popt_quintcb[11]
    quintcb_fit_alpha_2 = popt_quintcb[12]
    quintcb_fit_n_2 = popt_quintcb[13]
    quintcb_fit_N_2 = popt_quintcb[14]
    ##### 218Po Peak
    quintcb_fit_mu_3 = popt_quintcb[15]
    quintcb_fit_sigma_3 = popt_quintcb[16]
    quintcb_fit_alpha_3 = popt_quintcb[17]
    quintcb_fit_n_3 = popt_quintcb[18]
    quintcb_fit_N_3 = popt_quintcb[19]
    ##### 214Po Peak
    quintcb_fit_mu_4 = popt_quintcb[20]
    quintcb_fit_sigma_4 = popt_quintcb[21]
    quintcb_fit_alpha_4 = popt_quintcb[22]
    quintcb_fit_n_4 = popt_quintcb[23]
    quintcb_fit_N_4 = popt_quintcb[24]
    #### Generating single Crystal Ball data.
    Ra226_quintcb_fit_x_values, Ra226_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_0, sigma=quintcb_fit_sigma_0, alpha=quintcb_fit_alpha_0, n=quintcb_fit_n_0, N=quintcb_fit_N_0)
    Po210_quintcb_fit_x_values, Po210_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1)
    Rn222_quintcb_fit_x_values, Rn222_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_2, sigma=quintcb_fit_sigma_2, alpha=quintcb_fit_alpha_2, n=quintcb_fit_n_2, N=quintcb_fit_N_2)
    Po218_quintcb_fit_x_values, Po218_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_3, sigma=quintcb_fit_sigma_3, alpha=quintcb_fit_alpha_3, n=quintcb_fit_n_3, N=quintcb_fit_N_3)
    Po214_quintcb_fit_x_values, Po214_quintcb_fit_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=crystal_ball_function, mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4)
    
    print("Quintuple Crystal Ball fit successfully executed")
    
    ### Generating single Gaussian data
    #small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_2, A=5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    #crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_2, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2, alpha=qcb_fit_alpha_2, n=qcb_fit_n_2, N=qcb_fit_N_2)
    #scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    #gauss_Po218_x_values, gauss_Po218_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_2, sigma=qcb_fit_sigma_2)
    #small_gauss_value_at_peak = gauss_function(x=qcb_fit_mu_3, A=5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)
    #crystal_ball_value_at_peak = crystal_ball_function(x=qcb_fit_mu_3, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3, alpha=qcb_fit_alpha_3, n=qcb_fit_n_3, N=qcb_fit_N_3)
    #scaling_factor = crystal_ball_value_at_peak/small_gauss_value_at_peak
    #gauss_Po214_x_values, gauss_Po214_y_values = get_function_values_for_plot(x_min=1000, x_max=9000, stepwidth=1, function=gauss_function, A=scaling_factor*5, mu=qcb_fit_mu_3, sigma=qcb_fit_sigma_3)

    ### Generating residual data
    res_x_data = []
    res_y_data = []
    for i in range(len(file["adc_channel"])):
        res_x_data.append(file["adc_channel"][i])
        res_y_data.append((file["counts"][i]-quint_crystal_ball_function(x=file["adc_channel"][i], mu_0=quintcb_fit_mu_0, sigma_0=quintcb_fit_sigma_0, alpha_0=quintcb_fit_alpha_0, n_0=quintcb_fit_n_0, N_0=quintcb_fit_N_0, mu_1=quintcb_fit_mu_1, sigma_1=quintcb_fit_sigma_1, alpha_1=quintcb_fit_alpha_1, n_1=quintcb_fit_n_1, N_1=quintcb_fit_N_1, mu_2=quintcb_fit_mu_2, sigma_2=quintcb_fit_sigma_2, alpha_2=quintcb_fit_alpha_2, n_2=quintcb_fit_n_2, N_2=quintcb_fit_N_2, mu_3=quintcb_fit_mu_3, sigma_3=quintcb_fit_sigma_3, alpha_3=quintcb_fit_alpha_3, n_3=quintcb_fit_n_3, N_3=quintcb_fit_N_3, mu_4=quintcb_fit_mu_4, sigma_4=quintcb_fit_sigma_4, alpha_4=quintcb_fit_alpha_4, n_4=quintcb_fit_n_4, N_4=quintcb_fit_N_4))/np.sqrt(file["counts"][i]))
    
    ### Printing Fit Results.
    print("Fit Data for the 226Ra Peak: mu_0={}adc, sigma_0={}adc, alpha_0={}, n_0={}, N_0={}".format(quintcb_fit_mu_0, quintcb_fit_sigma_0, quintcb_fit_alpha_0, quintcb_fit_n_0, quintcb_fit_N_0))
    print("Fit Data for the 210Po Peak: mu_1={}adc, sigma_1={}adc, alpha_1={}, n_1={}, N_1={}".format(quintcb_fit_mu_1, quintcb_fit_sigma_1, quintcb_fit_alpha_1, quintcb_fit_n_1, quintcb_fit_N_1))
    print("Fit Data for the 222Rn Peak: mu_2={}adc, sigma_2={}adc, alpha_2={}, n_2={}, N_2={}".format(quintcb_fit_mu_2, quintcb_fit_sigma_2, quintcb_fit_alpha_2, quintcb_fit_n_2, quintcb_fit_N_2))
    print("Fit Data for the 218Po Peak: mu_3={}adc, sigma_3={}adc, alpha_3={}, n_3={}, N_3={}".format(quintcb_fit_mu_3, quintcb_fit_sigma_3, quintcb_fit_alpha_3, quintcb_fit_n_3, quintcb_fit_N_3))    
    print("Fit Data for the 214Po Peak: mu_4={}adc, sigma_4={}adc, alpha_4={}, n_4={}, N_4={}".format(quintcb_fit_mu_4, quintcb_fit_sigma_4, quintcb_fit_alpha_4, quintcb_fit_n_4, quintcb_fit_N_4))

# %%
##################################################################################
###   Analysis
##################################################################################

if FLAG_analysis == True:

    ### Literature values (nucleide.ord) for the respective alpha energies.
    ### Denoted behind is the total Q value of the alpha decay.
    energy_226Ra_alpha = 4784.34 #4870.62
    energy_210Po_alpha = 5304.33 #5407.45
    energy_222Rn_alpha = 5489.48 #5590.3    
    energy_218Po_alpha = 6002.35 #6114.68
    energy_214Po_alpha = 7686.82 #7833.46

    #######################################################################################################################################
    ###   Checking whether the distance of the peak fits matches the energy distances.
    #######################################################################################################################################
    
    FLAG_pp = "five" # "two"
    
    if FLAG_pp == "five":
        ### Energy Channel Relation (Inferred from five Peaks).
        #### Writing the energies (in keV), peak positions and errors (in adc) of 226Ra, 210Po, 222Rn, 218Po, 214Po into lists.
        energy_list = [energy_226Ra_alpha, energy_210Po_alpha, energy_222Rn_alpha, energy_218Po_alpha, energy_214Po_alpha]
        channel_list = [quintcb_fit_mu_0, quintcb_fit_mu_1, quintcb_fit_mu_2, quintcb_fit_mu_3, quintcb_fit_mu_4]
        sigma_channel_list = [np.sqrt(np.diag(pcov_quintcb))[0], np.sqrt(np.diag(pcov_quintcb))[5], np.sqrt(np.diag(pcov_quintcb))[10], np.sqrt(np.diag(pcov_quintcb))[15], np.sqrt(np.diag(pcov_quintcb))[20]]
        #### Fitting a linear function to the energy and channel values of the alpha peaks.
        popt_lin, pcov_lin = curve_fit(f=linear_function, xdata=energy_list, ydata=channel_list, sigma=sigma_channel_list, absolute_sigma=True, method='lm')
        m = popt_lin[0]
        sigma_m = np.sqrt(np.diag(pcov_lin))[0]
        t = popt_lin[1]
        sigma_t = np.sqrt(np.diag(pcov_lin))[1]
        #### Retrieving the theoretical values for the peak positions and their errors.
        erg_channel_list = [0,0,0,0,0]
        sigma_erg_channel_list = [0,0,0,0,0]
        for i in range(len(erg_channel_list)):
            erg_channel_list[i] = (m*energy_list[i])+t
            sigma_erg_channel_list[i] = np.sqrt(((energy_list[i]*sigma_m)**2)+1)

    if FLAG_pp == "two":
        ### Energy Channel Relation (Inferred from two Peaks).
        #### The energy channel relation within these few lines of code are inferred solely from the 214Po and 218Po peaks.
        #### The reasonning behind this is to check, whether the peaks of 226Ra, 222Rn and 210Po show up where one would expect them to.
        energy_channel_high = [energy_214Po_alpha, quintcb_fit_mu_4]
        energy_channel_low = [energy_218Po_alpha, quintcb_fit_mu_3]
        ch_value_226Ra = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_226Ra_alpha)
        ch_value_210Po = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_210Po_alpha)
        ch_value_222Rn = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_222Rn_alpha)
        ch_value_218Po = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_218Po_alpha)
        ch_value_214Po = energy_channel_relation(energy_channel_list_high=energy_channel_high, energy_channel_list_low=energy_channel_low, energy_value=energy_214Po_alpha)
        ### Printing Analysis Results.
        print("Analysis Completed Successfully.") 
        print("The channels corresponding to the 226Ra ({}keV), 210Po ({}keV) and 222Rn ({}keV) peak respectively are {} adc and {} adc.".format(energy_226Ra_alpha, energy_210Po_alpha, energy_222Rn_alpha, ch_value_226Ra, ch_value_210Po, ch_value_222Rn))

    #######################################################################################################################################
    ###   Reading out the resolution of certain energy peaks
    #######################################################################################################################################
    
    peak_channel = quintcb_fit_mu_4
    sigma_channel = quintcb_fit_sigma_4
    fwhm_channel = 2*np.sqrt(2*math.log(2))*sigma_channel
    resolution_channel = (fwhm_channel/peak_channel)*100
    peak_energy = energy_214Po_alpha
    sigma_energy = ((energy_214Po_alpha-energy_218Po_alpha)/(quintcb_fit_mu_4-quintcb_fit_mu_3))*quintcb_fit_sigma_4
    fwhm_energy = 2*np.sqrt(2*math.log(2))*sigma_energy
    resolution_energy = (fwhm_energy/peak_energy)*100
    print("resolution (channels): peak = {} adc, sigma = {} adc, resolution = {}%.".format(peak_channel, sigma_channel, resolution_channel))
    print("resolution (energy): peak = {} adc, sigma = {} adc, resolution = {}%.".format(peak_energy, sigma_energy, resolution_energy))
# Out:
# resolution (channels): peak = 7628.100055389463 adc, sigma = 255.34951598100446 adc, resolution = 7.882725113131986%.
# resolution (energy): peak = 7686.82 adc, sigma = 187.0297262802763 adc, resolution = 5.729565001670995%.

# %%
##################################################################################
###   Plotting.
##################################################################################

if FLAG_plot == True:

    #######################################################################################################################################
    ###   Defining Figure and Frame
    #######################################################################################################################################

    fig=plt.figure(figsize=(21, 10.5), dpi=150)  ### <----- The number specified within "figsize=()" correspond to the size of the final image in inches. Correspondingly the dpi (dots per inch) value is setting the resolution of your figure.
    
    if FLAG_plot_residual_canvas == True:
        frame1=fig.add_axes((.1,.3,.8,.6)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))
    else:
        frame1=fig.add_axes((.1,.1,.8,.8)) ### <----- This specifies a canvas within the defined figure. The argument syntax (quantities relative to the figure x and y dimensions respectively) is as follows: ("x position of the lower lefthand corner", "y position of the lower lefthand corner", "size in x direction", "size in y direction"). A usual plot is generated with the default values: frame1=fig.add_axes((0.1,0.1,0.8,0.8))

    #######################################################################################################################################
    ###   Plotting Data
    #######################################################################################################################################
    
    ### Plotting histogram, scatter plot or line plot.
    #plt.hist2d(file_a["number_of_electrons"], file_a["S1_PE"], bins=[142,40], range=[[0,142],[0.5,40]], cmin=1, norm=LogNorm(), cmap=plt.cm.jet)
    #plt.scatter(file["S1_PE"], file["S2_PE"], marker="o", c="cyan", alpha=1, label="equally distributed ER events") # alpha = 0.002    
    #plt.plot(qcb_fit_x_values, qcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Quadruple Crystal Ball Fit")
        
    ### Plotting the data itself.
    plt.scatter(file["adc_channel"], file["counts"], marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None, label="$^{226}\mathrm{Ra}$ Spectrum Data")
    
    if FLAG_fits == True:
        
        ### Plotting the quadruple Crystal Ball fit.
        plt.plot(quintcb_fit_x_values, quintcb_fit_y_values, marker=",", linewidth=5, c="cyan", alpha=1, label="Quintuple Crystal Ball Fit")
    
        ### Plotting the Crystal Ball curves resulting from the quadruple Crystal Ball fit.
        plt.plot(Ra226_quintcb_fit_x_values, Ra226_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{226}\mathrm{Ra}$")
        plt.plot(Rn222_quintcb_fit_x_values, Rn222_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{222}\mathrm{Rn}$")
        plt.plot(Po218_quintcb_fit_x_values, Po218_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{218}\mathrm{Po}$")
        plt.plot(Po214_quintcb_fit_x_values, Po214_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{214}\mathrm{Po}$")
        plt.plot(Po210_quintcb_fit_x_values, Po210_quintcb_fit_y_values, marker=",", linewidth=5, c="purple", alpha=0.75, label="Crystal Ball Curve: $^{210}\mathrm{Po}$")
    
        ### Plotting the relevant gaussians resulting from the quadruple Crystal Ball fit.
        #plt.plot(gauss_Po218_x_values, gauss_Po218_y_values, marker=",", linewidth=5, c="blue", alpha=0.75, label="Gaussian Curve: $^{218}\mathrm{Po}$")
        #plt.plot(gauss_Po214_x_values, gauss_Po214_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Curve: $^{214}\mathrm{Po}$")
    
        ### Plotting a gaussian fit for the 214Po Peak (the fit is done only for the right half).
        #plt.plot(gauss_fit_x_values, gauss_fit_y_values, marker=",", linewidth=5, c="red", alpha=0.75, label="Gaussian Fit: $\mu_\mathrm{G}=\,$" +str(gauss_fit_mu) +"$,\,\,\sigma_\mathrm{G}=\,$" +str(gauss_fit_sigma))
    
    #######################################################################################################################################
    ###   Axes Settings
    #######################################################################################################################################
    
    ### Title
    title_string = "$\\boldsymbol{^{226}\mathrm{Ra}}$ \\textbf{Spectrum}"
    plt.title(title_string, fontsize=28, pad=15)
    
    ### Axes ---> Labels
        #plt.xlabel("\\textbf{$\\boldsymbol{F=ma}$}", fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    xaxisstring = "\\textbf{Energy }$\\boldsymbol{[\\mathrm{adc}]}$"
    yaxisstring = "\\textbf{Counts per adc}"
    if FLAG_plot_residual_canvas == True:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 186)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    else:
        plt.xlabel(xaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    plt.ylabel(yaxisstring, fontsize=24, labelpad = 14)   # <--- Specifying the x-axis label along with its (self explaining) properties.
    
    ### Axes ---> Formatting
    axes = plt.gca()
    axes.tick_params(axis='both')
    for axis in ['top','bottom','left','right']:
        axes.spines[axis].set_linewidth(2.2)
        
    ### Axes ---> Range  
    plt.xlim(2000,8350) #plt.xlim(0,8500)
    plt.ylim(0,200)
    #plt.ylim(100,2500)
    #plt.yscale("log")
    
    ### Axes ---> Ticks
    axes.xaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
    axes.yaxis.set_minor_locator(AutoMinorLocator(5))
    plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
    if FLAG_plot_residual_canvas == True:
        plt.setp(axes.get_xticklabels(), visible=False)
    #plt.yticks([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0])
    #plt.xticks([])
    
    ### Axes ---> Shading
    #plt.fill_between(m_1_gummy_bears_1sigma,p_Tab_1_gummy_bears_1sigma, color='yellow',label='$\sigma_{x}$-Intervall')
    FLAG_shading = False
    if FLAG_shading == True:
        for i in [0,1,2,3,4]:
            shade_x_values = np.arange(erg_channel_list[i]-sigma_erg_channel_list[i], erg_channel_list[i]+sigma_erg_channel_list[i], 0.5)
            shade_y_values = []
            if i == 0:
                for j in range(len(shade_x_values)):
                    shade_y_values.append(crystal_ball_function(x=shade_x_values[j], mu=quintcb_fit_mu_0, sigma=quintcb_fit_sigma_0, alpha=quintcb_fit_alpha_0, n=quintcb_fit_n_0, N=quintcb_fit_N_0))
            if i == 1:
                for j in range(len(shade_x_values)):
                    shade_y_values.append(crystal_ball_function(x=shade_x_values[j], mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1))
            if i == 2:
                for j in range(len(shade_x_values)):
                    shade_y_values.append(crystal_ball_function(x=shade_x_values[j], mu=quintcb_fit_mu_2, sigma=quintcb_fit_sigma_2, alpha=quintcb_fit_alpha_2, n=quintcb_fit_n_2, N=quintcb_fit_N_2))
            if i == 3:
                for j in range(len(shade_x_values)):
                    shade_y_values.append(crystal_ball_function(x=shade_x_values[j], mu=quintcb_fit_mu_3, sigma=quintcb_fit_sigma_3, alpha=quintcb_fit_alpha_3, n=quintcb_fit_n_3, N=quintcb_fit_N_3))
            if i == 4:
                for j in range(len(shade_x_values)):
                    shade_y_values.append(crystal_ball_function(x=shade_x_values[j], mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4))
            plt.fill_between(x=shade_x_values, y1=shade_y_values, y2=0, color='0.8', alpha=0.5)
            vertical_line_list_x = [erg_channel_list[i], erg_channel_list[i]]
            if i == 0:
                for j in range(len(shade_x_values)):
                    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[0], mu=quintcb_fit_mu_0, sigma=quintcb_fit_sigma_0, alpha=quintcb_fit_alpha_0, n=quintcb_fit_n_0, N=quintcb_fit_N_0)]
            if i == 1:
                for j in range(len(shade_x_values)):
                    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[1], mu=quintcb_fit_mu_1, sigma=quintcb_fit_sigma_1, alpha=quintcb_fit_alpha_1, n=quintcb_fit_n_1, N=quintcb_fit_N_1)]
            if i == 2:
                for j in range(len(shade_x_values)):
                    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[2], mu=quintcb_fit_mu_2, sigma=quintcb_fit_sigma_2, alpha=quintcb_fit_alpha_2, n=quintcb_fit_n_2, N=quintcb_fit_N_2)]
            if i == 3:
                for j in range(len(shade_x_values)):
                    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[3], mu=quintcb_fit_mu_3, sigma=quintcb_fit_sigma_3, alpha=quintcb_fit_alpha_3, n=quintcb_fit_n_3, N=quintcb_fit_N_3)]
            if i == 4:
                for j in range(len(shade_x_values)):
                    vertical_line_list_y = [0, crystal_ball_function(x=erg_channel_list[4], mu=quintcb_fit_mu_4, sigma=quintcb_fit_sigma_4, alpha=quintcb_fit_alpha_4, n=quintcb_fit_n_4, N=quintcb_fit_N_4)]
            plt.plot(vertical_line_list_x, vertical_line_list_y, color='black',linewidth=2.2,linestyle='-')
    
 
    
    
    #plt.axvline(x=erg_channel_list[1], color="black")
    #plt.axvline(x=erg_channel_list[2], color="black")
    #plt.axvline(x=erg_channel_list[3], color="black")
    #plt.axvline(x=erg_channel_list[4], color="black")

    #plt.fill_between(x=np.asarray(Po214_quintcb_fit_x_values), y1=np.asarray(Po214_quintcb_fit_y_values), y2=0, where=[np.asarray(Rn222_quintcb_fit_x_values) >= erg_channel_list[0]-sigma_erg_channel_list[0], np.asarray(Po214_quintcb_fit_x_values)<=erg_channel_list[0]+sigma_erg_channel_list[0]], color='yellow')#,label='$\sigma_{x}$-Intervall')
    #axes.axvspan(erg_channel_list[1]-sigma_erg_channel_list[1], erg_channel_list[1]+sigma_erg_channel_list[1], alpha=0.5, color='0.8')
    #axes.axvspan(erg_channel_list[2]-sigma_erg_channel_list[2], erg_channel_list[2]+sigma_erg_channel_list[2], alpha=0.5, color='0.8')
    #axes.axvspan(erg_channel_list[3]-sigma_erg_channel_list[3], erg_channel_list[3]+sigma_erg_channel_list[3], alpha=0.5, color='0.8')
    #axes.axvspan(erg_channel_list[4]-sigma_erg_channel_list[4], erg_channel_list[4]+sigma_erg_channel_list[4], alpha=0.5, color='0.8')
    ### Axes ---> Horizontal/Vertical Lines
    #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
    #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)

    #######################################################################################################################################
    ###   Colorbar
    #######################################################################################################################################
    
    #cbar = plt.colorbar() #label="Counts") #, fontsize=28)
    #cbar.set_label(label="Counts", fontsize=24, labelpad=-105)
    #cbar.outline.set_linewidth(2.2)
    #cbar.ax.tick_params(labelsize=20)

    #######################################################################################################################################
    ###   Plot Size
    #######################################################################################################################################
    
    # For a figure optimized for 4:3 ratio.
    plt.subplots_adjust(left=0.10, right=0.80, top=0.93, bottom=0.10)
    # For a figure optimized for 16:9 ratio.
    #plt.subplots_adjust(left=0.05, right=1.10, top=0.93, bottom=0.10)

    #######################################################################################################################################
    ###   Legend
    #######################################################################################################################################
    
    if FLAG_legend == True:
    
        if FLAG_plot_residual_canvas == True:
            handles, labels = plt.gca().get_legend_handles_labels()
            order = [5,0,1,3,2,4]
            leg = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc=3, bbox_to_anchor=(0.69,0.51), fontsize = 18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
        else:
            leg = plt.legend(loc=3, bbox_to_anchor=(0.68,0.71), fontsize=18, frameon=True, shadow=False, edgecolor='black', fancybox=False)
            
        for line in leg.get_lines(): # enumerated
            line.set_linewidth(4)
        leg.get_frame().set_linewidth(2.5)
        for lh in leg.legendHandles: 
            lh.set_alpha(1)

    #######################################################################################################################################
    ###   Text
    #######################################################################################################################################
    
    if FLAG_peak_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.91, 0.54, "$\\boldsymbol{^{214}\mathrm{Po}}$" +"\\\\[0.4cm]" +"$\\,\\,\\,\\,\\,R=$" +"{:.2f}".format(resolution_channel) +"$\\,\\%$", fontsize=22, transform = axes.transAxes)            
            plt.text(0.54, 0.46, "$\\boldsymbol{^{218}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.36, 0.47, "$\\boldsymbol{^{222}\mathrm{Rn}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.32, 0.08, "$\\boldsymbol{^{210}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.19, 0.28, "$\\boldsymbol{^{226}\mathrm{Ra}}$", fontsize=22, transform = axes.transAxes)
        else:
            plt.text(0.91, 0.54, "$\\boldsymbol{^{214}\mathrm{Po}}$" +"\\\\[0.4cm]" +"$\\,\\,\\,\\,\\,R=$" +"{:.2f}".format(resolution_channel) +"$\\,\\%$", fontsize=22, transform = axes.transAxes)            
            plt.text(0.54, 0.46, "$\\boldsymbol{^{218}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.36, 0.47, "$\\boldsymbol{^{222}\mathrm{Rn}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.32, 0.08, "$\\boldsymbol{^{210}\mathrm{Po}}$", fontsize=22, transform = axes.transAxes)
            plt.text(0.19, 0.28, "$\\boldsymbol{^{226}\mathrm{Ra}}$", fontsize=22, transform = axes.transAxes)
        
    if FLAG_setup_text == True:
        if FLAG_plot_residual_canvas == True:
            plt.text(0.02, 0.35, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        else:
            plt.text(0.02, 0.450, write_parameters_to_canvas_text_block(filestring=txt_filestring), fontsize=22, transform = axes.transAxes)
        
    #######################################################################################################################################
    ###   Residual Canvas
    #######################################################################################################################################
    
    if FLAG_plot_residual_canvas == True:
        frame2=fig.add_axes((.1,.1,.8,.2))
    
        # Plotting
        plt.scatter(res_x_data, res_y_data, marker="o", s=5, c="#004A99", alpha=0.85, linewidth=None)#, label="Residuals")
    
        # Axes Settings
        plt.ylabel("\\textbf{Residuals} $\\boldsymbol{[\\mathrm{\\sigma}]}$", fontsize=24, labelpad = 9)   # <--- Specifying the x-axis label along with its (self explaining) properties.
        axes2 = plt.gca()
        axes2.tick_params(axis='both')
        for axis in ['top','bottom','left','right']:
            axes2.spines[axis].set_linewidth(2.2)
        ## Axes ---> Range  
        plt.xlim(2000,8350)
        plt.ylim(-3.5,+3.5)
        #plt.yscale("log")
        # Axes ---> Ticks
        axes2.xaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='minor', direction='in', labelsize=20, top=True, right=True, width=1.2, length=6)
        axes2.yaxis.set_minor_locator(AutoMinorLocator(5))
        plt.tick_params(which='major', direction='in', labelsize=20, top=True, right=True, width=1.2, length=12)
        plt.yticks([-2, 0, 2])
        #plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
        # Axes ---> Shading
        #axes.axvspan(0, 23.0, alpha=0.5, color='0.8')
        # Axes ---> Horizontal/Vertical Lines
        #axes.axhline(y=1.0, xmin=0, xmax=60, color="black", linestyle="--", linewidth=0.5)
        #axes.axvline(x=23.0, ymin=0, ymax=6, color="black", linestyle="--", linewidth=0.5)
        axes2.axhline(y=0.0, xmin=0, xmax=10000, color="black", linestyle="--", linewidth=2.0)
    
    #######################################################################################################################################
    ###   Saving
    #######################################################################################################################################
    
    if FLAG_save == True:
        save_string = "spectrum_plot_collection_voltage_1000"
        format_string = ".png"
        fig.savefig("Measurements/" +get_runstring(filestring=txt_filestring) +"/" +get_runstring(filestring=txt_filestring) +"__" +get_measurementstring(filestring=txt_filestring) +"__" +save_string +format_string)
